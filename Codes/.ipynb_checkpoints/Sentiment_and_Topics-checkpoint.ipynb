# %% [markdown]
# # Sentiment and Topic Analysis

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/BSE/TextMining')

# %% [markdown]
# ## Preprocessing

# %%
# !pip install emoji
# Out:
# Collecting emoji
#   Downloading emoji-1.7.0.tar.gz (175 kB)
# Building wheels for collected packages: emoji
#   Building wheel for emoji (setup.py): started
#   Building wheel for emoji (setup.py): finished with status 'done'
#   Created wheel for emoji: filename=emoji-1.7.0-py3-none-any.whl size=171030 sha256=42e1d98991bea10b2eed4f5af80b00e950ab37bc9636ca2c803de4de26cc03f3
#   Stored in directory: c:\users\stefan\appdata\local\pip\cache\wheels\5e\8c\80\c3646df8201ba6f5070297fe3779a4b70265d0bfd961c15302
# Successfully built emoji
# Installing collected packages: emoji
# Successfully installed emoji-1.7.0

# %%
import numpy as np
import pandas as pd
import emoji
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem import SnowballStemmer   
from nltk.stem.wordnet import WordNetLemmatizer
import re

import math
import warnings
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Stefan
# [nltk_data]     Hoeller\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
stopwords_eng =stopwords.words("english")
stopwords_es =stopwords.words("spanish")
stops = stopwords_eng + stopwords_es

def cleanTweets(s):
    #Function to clean tweets, for now i am keeping emojis and hashtags. Alternative version
    if type(s)==np.float:
        return ""
    #Demojize text
    s=emoji.demojize(s)
    
    #Remove new lines, etc.
    s = s.replace(r'<lb>', "\n")
    s = s.replace(r'<tab>', "\i")
    s = re.sub(r'<br */*>', "\n", s)
    s = s.replace("&lt;", "<").replace("&gt;", ">").replace("&amp;", "&")
    s = s.replace("&amp;", "&")
    s = s.replace("\n", " ")
    
    # markdown urls
    s = re.sub(r'\(https*://[^\)]*\)', "", s)
    # normal urls
    s = re.sub(r'https*://[^\s]*', "", s)
    #s = re.sub(r'_+', ' ', s)
    s = re.sub(r'"+', '"', s)
    #Remove punctuation    
    s = re.sub('[()!?]', ' ', s)
    s = re.sub('\[.*?\]',' ', s)
    # custom removals
    s = re.sub(r'@[A-Za-z0-9_]+', "", s) # replace mentions
    s = re.sub(r':[^:]+','',s) # remove demojized text
    
    #Split multiword hashtags into individual words - they could contain spin
    #s = re.sub(r'#(\w+)', rep, s) # split hashtags
    s = re.sub(r'#[A-Za-z0-9_]+', "", s) # remove hashtags
    
    s = re.sub(r'[0-9]','',s) #remove digits
    
    s=s.lower()
    
    #Remove stopwords
    s=s.split()
    s= [w for w in s if not s in stops]
    
    
    s=" ".join(word for word in s)
    
    return str(s)


stemmer_eng=SnowballStemmer("english")
stemmer_es=SnowballStemmer("spanish")
lem = WordNetLemmatizer()

def stem_lematize(s, modulation):
    tokens = re.split(r'\W+', s)
    stems = []
    for token in tokens:
        if modulation==1:
            eng=stemmer_es.stem(token)
            stems.append(stemmer_es.stem(eng))
        if modulation==2:
            stems.append(lem.lemmatize(token))
        if modulation==0:
            stems.append(tokens)
    s=" ".join(word for word in stems)
    return s

# %%
#corpus_data=pd.read_csv("Data/all_tweets_filtered.csv")
# Out:
# C:\Users\Stefan Hoeller\AppData\Local\Temp\ipykernel_4212\3927701885.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   corpus_data=pd.read_csv("Data/all_tweets_filtered.csv")

# %%
df=pd.read_csv("all_tweets_filtered_final.csv")

# %%
df['cleaned_text'] = [cleanTweets(text) for text in df['text']]

# %%
df['stem_text'] = [stem_lematize(text, 1) for text in df['cleaned_text']]

# %%
df.to_csv('all_tweets_stem.csv')

# %%
df['cleaned_text']

# %%
df['stem_text']

# %% [markdown]
# # Sentiment Analysis & LDA

# %%
#Import Data
#df=pd.read_csv("Data/all_tweets_preprocessed.csv")
# Out:
# C:\Users\Stefan Hoeller\AppData\Local\Temp\ipykernel_21296\3691274396.py:2: DtypeWarning: Columns (14) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv("Data/all_tweets_preprocessed.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1009648 entries, 0 to 1009647
# Data columns (total 31 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   Unnamed: 0                             1009648 non-null  int64
#  1   level_0                                1009648 non-null  int64
#  2   index                                  973904 non-null   float64
#  3   Unnamed: 0.1                           973904 non-null   float64
#  4   id                                     1009648 non-null  int64
#  5   author_id                              1009648 non-null  int64
#  6   created_at                             1009648 non-null  object
#  7   text                                   1009648 non-null  object
#  8   public_metrics.like_count              1009648 non-null  int64
#  9   public_metrics.quote_count             1009648 non-null  int64
#  10  public_metrics.reply_count             1009648 non-null  int64
#  11  public_metrics.retweet_count           1009648 non-null  int64
#  12  author.username                        1009648 non-null  object
#  13  Country                                1009648 non-null  object
#  14  Categorie                              1009648 non-null  object
#  15  Time                                   1009648 non-null  object
#  16  Left/Right                             112281 non-null   object
#  17  author.entities.description.hashtags   248934 non-null   object
#  18  author.public_metrics.following_count  1009648 non-null  int64
#  19  in_reply_to_user_id                    225163 non-null   float64
#  20  retweeted_user_id                      486375 non-null   float64
#  21  quoted_user_id                         76606 non-null    float64
#  22  author.name                            1009648 non-null  object
#  23  author.description                     996400 non-null   object
#  24  possibly_sensitive                     1009648 non-null  bool
#  25  Date                                   1009648 non-null  object
#  26  Day Protest                            1009648 non-null  object
#  27  Days since                             1009648 non-null  int64
#  28  cleaned_text                           1009648 non-null  object
#  29  stem_text                              1009648 non-null  object
#  30  sentiment                              1009648 non-null  float64
# dtypes: bool(1), float64(6), int64(10), object(14)
# memory usage: 232.1+ MB

# %% [markdown]
# ## Sentiment Analysis Method 1

# %%
# !pip install sentiment-analysis-spanish
# Out:
# Collecting sentiment-analysis-spanish
#   Downloading sentiment_analysis_spanish-0.0.25-py3-none-any.whl (30.0 MB)
#      |████████████████████████████████| 30.0 MB 1.5 MB/s
# Installing collected packages: sentiment-analysis-spanish
# Successfully installed sentiment-analysis-spanish-0.0.25

# %%
df['cleaned_text'] = df['cleaned_text'].astype(str)

# %%
from sentiment_analysis_spanish import sentiment_analysis

def get_sentiment(data,column):
    output=[]
    sent=sentiment_analysis.SentimentAnalysisSpanish()
    for index, row in data.iterrows():
        score=sent.sentiment(row[column])
        output.append(score) 
    data["sentiment"]=output  #Output between 0 and 1, low numbers negative, high numbers positive 
    return data

df_1=get_sentiment(df,"cleaned_text")

# %%
df_1.groupby(["Country","Categorie","Time"])["sentiment"].mean()
# Out:
# Country   Categorie   Time
# Chile     Celebrity   After     0.227027
#                       Before    0.259193
#                       During    0.222401
#           Politician  After     0.174303
#                       Before    0.205686
#                       During    0.171343
# Colombia  Celebrity   After     0.221563
#                       Before    0.209066
#                       During    0.196717
#           Politician  After     0.170907
#                       Before    0.170510
#                       During    0.165744
# Name: sentiment, dtype: float64

# %%
df_1[df_1["sentiment"]>0.8]

# %%
df_1.to_csv('all_tweets_sentiment_1.csv')

# %%
#Plot sentiment by day to check for date impact

# %%
df_all=pd.read_csv("G:/My Drive/BSE/TextMining/all_tweets_sentiment_1.csv")

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1009648 entries, 0 to 1009647
# Data columns (total 32 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   Unnamed: 0.2                           1009648 non-null  int64
#  1   Unnamed: 0                             1009648 non-null  int64
#  2   level_0                                1009648 non-null  int64
#  3   index                                  973904 non-null   float64
#  4   Unnamed: 0.1                           973904 non-null   float64
#  5   id                                     1009648 non-null  int64
#  6   author_id                              1009648 non-null  int64
#  7   created_at                             1009648 non-null  object
#  8   text                                   1009648 non-null  object
#  9   public_metrics.like_count              1009648 non-null  int64
#  10  public_metrics.quote_count             1009648 non-null  int64
#  11  public_metrics.reply_count             1009648 non-null  int64
#  12  public_metrics.retweet_count           1009648 non-null  int64
#  13  author.username                        1009648 non-null  object
#  14  Country                                1009648 non-null  object
#  15  Categorie                              1009648 non-null  object
#  16  Time                                   1009648 non-null  object
#  17  Left/Right                             112281 non-null   object
#  18  author.entities.description.hashtags   248934 non-null   object
#  19  author.public_metrics.following_count  1009648 non-null  int64
#  20  in_reply_to_user_id                    225163 non-null   float64
#  21  retweeted_user_id                      486375 non-null   float64
#  22  quoted_user_id                         76606 non-null    float64
#  23  author.name                            1009648 non-null  object
#  24  author.description                     996400 non-null   object
#  25  possibly_sensitive                     1009648 non-null  bool
#  26  Date                                   1009648 non-null  object
#  27  day_protest                            1009648 non-null  object
#  28  days_since                             1009648 non-null  int64
#  29  cleaned_text                           952393 non-null   object
#  30  stem_text                              952393 non-null   object
#  31  sentiment                              1009648 non-null  float64
# dtypes: bool(1), float64(6), int64(11), object(14)
# memory usage: 247.5+ MB

# %%
#create mapping table, 1 row per author_id
map_table = df_all.drop_duplicates(subset=['author_id'])

# %%
df_all=df_all.rename(columns={"Days since":"days_since","Day Protest":"day_protest"})

# %%
sns.set_palette("icefire")
sns.set(rc={'figure.figsize':(10,7)})
sent=sns.lineplot(data=df_all,x="days_since",y="sentiment",hue="Country")

sent.set_title( "Sentiment comparison before, during and after the protest")
sent.set_xlabel( "Timeline in Days (0: Start Protest)")
sent.set_ylabel( "Sentiment Score (0: Negative, 1: Positive)")
# Out:
# Text(0, 0.5, 'Sentiment Score (0: Negative, 1: Positive)')

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(data=df_all,x="days_since",y="sentiment",hue="Country",style="Categorie")
# Out:
# <AxesSubplot:xlabel='days_since', ylabel='sentiment'>

# %%
sns.set()
sns.set(rc={'figure.figsize':(15,7)})
#define plotting region (1 row, 2 columns)
fig, axes = plt.subplots(1, 2)

#create boxplot in each subplot
pl1=sns.lineplot(data=df_all[df_all["Country"]=="Chile"],x="days_since",y="sentiment",hue="Categorie",ax=axes[0])
pl2=sns.lineplot(data=df_all[df_all["Country"]=="Colombia"],x="days_since",y="sentiment",hue="Categorie",ax=axes[1])

pl1.set_title( "Sentiment in Chile")
pl1.set_xlabel( "Timeline in Days (0: Start Protest)")
pl1.set_ylabel( "Sentiment Score (0: Negative, 1: Positive)")
pl2.set_title( "Sentiment in Colombia")
pl2.set_xlabel( "Timeline in Days (0: Start Protest)")
pl2.set_ylabel( "Sentiment Score (0: Negative, 1: Positive)")
# Out:
# Text(0, 0.5, 'Sentiment Score (0: Negative, 1: Positive)')

# %% [markdown]
# **ANOVA**

# %%
df=df_all[df_all["Country"]=="Chile"]

# %%
from scipy import stats

keys = list(df.Time.unique())

values = []
for engine in keys:
    values.append(list(df.loc[df['Time'] == engine, 'sentiment']))

data = dict(zip(keys, values))

# stats f_oneway functions takes the groups as input and returns F and P-value
fvalue, pvalue = stats.f_oneway(data['Before'],
                                data['During'], 
                                data['After'])

print(f"Results of ANOVA test:\n The F-statistic is: {fvalue}\n The p-value is: {pvalue}")
#Highly significant

from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog=df['sentiment'], groups=df['Time'], alpha=0.05)
print(m_comp)
#All are different
# Out:
# Results of ANOVA test:
#  The F-statistic is: 740.7498643590787
#  The p-value is: 5.2e-322
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#  After Before   0.0306  -0.0  0.0282   0.033   True
#  After During  -0.0049   0.0 -0.0068 -0.0029   True
# Before During  -0.0355  -0.0 -0.0377 -0.0333   True
# ---------------------------------------------------

# %%
df=df_all[df_all["Country"]=="Colombia"]

from scipy import stats

keys = list(df.Time.unique())

values = []
for engine in keys:
    values.append(list(df.loc[df['Time'] == engine, 'sentiment']))

data = dict(zip(keys, values))

# stats f_oneway functions takes the groups as input and returns F and P-value
fvalue, pvalue = stats.f_oneway(data['Before'],
                                data['During'], 
                                data['After'])

print(f"Results of ANOVA test:\n The F-statistic is: {round(fvalue,2)}\n The p-value is: {round(pvalue,2)}")
#Highly significant

from statsmodels.stats.multicomp import pairwise_tukeyhsd

# perform multiple pairwise comparison (Tukey HSD)
m_comp = pairwise_tukeyhsd(endog=df['sentiment'], groups=df['Time'], alpha=0.05)
print(m_comp)
#All are different
# Out:
# Results of ANOVA test:
#  The F-statistic is: 194.57
#  The p-value is: 0.0
# Multiple Comparison of Means - Tukey HSD, FWER=0.05
# ===================================================
# group1 group2 meandiff p-adj  lower   upper  reject
# ---------------------------------------------------
#  After Before  -0.0077   0.0 -0.0102 -0.0053   True
#  After During  -0.0185  -0.0 -0.0208 -0.0162   True
# Before During  -0.0108  -0.0 -0.0129 -0.0086   True
# ---------------------------------------------------

# %% [markdown]
# **Right vs. Left**

# %%
politicians=df_all[df_all["Categorie"]=="Politician"]

# %%
sns.set()

#define plotting region (1 row, 2 columns)
fig, axes = plt.subplots(1, 2)

#create boxplot in each subplot
sns.lineplot(data=politicians[politicians["Country"]=="Colombia"],x="days_since",y="sentiment",hue="Left/Right",ax=axes[0])
sns.lineplot(data=politicians[politicians["Country"]=="Chile"],x="days_since",y="sentiment",hue="Left/Right",ax=axes[1])
# Out:
# <AxesSubplot:xlabel='days_since', ylabel='sentiment'>

# %%
politicians.groupby(["Country","Time","Left/Right"])["sentiment"].mean()
# Out:
# Country   Time    Left/Right
# Chile     After   Left          0.156093
#                   Right         0.212082
#           Before  Left          0.192049
#                   Right         0.231162
#           During  Left          0.170286
#                   Right         0.172149
# Colombia  After   Left          0.163902
#                   Right         0.181462
#           Before  Left          0.169223
#                   Right         0.173201
#           During  Left          0.164336
#                   Right         0.168406
# Name: sentiment, dtype: float64

# %% [markdown]
# ## Sentiment Analysis Method 2

# %% [markdown]
# **Pysentimiento - Getting the Data**

# %%
# !pip install pysentimiento
# Out:
# Collecting pysentimiento
#   Downloading pysentimiento-0.3.2-py3-none-any.whl (20 kB)
# Collecting torch<2.0.0,>=1.9.0
#   Downloading torch-1.11.0-cp38-cp38-win_amd64.whl (158.0 MB)
# Collecting transformers<5.0.0,>=4.11.3
#   Downloading transformers-4.17.0-py3-none-any.whl (3.8 MB)
# Requirement already satisfied: emoji<2.0.0,>=1.6.1 in c:\users\stefan\anaconda3\lib\site-packages (from pysentimiento) (1.7.0)
# Collecting sklearn<0.1,>=0.0
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
# Collecting datasets<2.0.0,>=1.13.3
#   Downloading datasets-1.18.4-py3-none-any.whl (312 kB)
# Requirement already satisfied: pandas in c:\users\stefan\anaconda3\lib\site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (1.2.4)
# Collecting tqdm>=4.62.1
#   Downloading tqdm-4.63.1-py2.py3-none-any.whl (76 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py38-none-any.whl (128 kB)
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.2.0-py3-none-any.whl (134 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\stefan\anaconda3\lib\site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (1.20.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp38-cp38-win_amd64.whl (29 kB)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp38-cp38-win_amd64.whl (555 kB)
# Collecting huggingface-hub<1.0.0,>=0.1.0
#   Downloading huggingface_hub-0.4.0-py3-none-any.whl (67 kB)
# Collecting pyarrow!=4.0.0,>=3.0.0
#   Downloading pyarrow-7.0.0-cp38-cp38-win_amd64.whl (16.1 MB)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: packaging in c:\users\stefan\anaconda3\lib\site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (20.9)
# Requirement already satisfied: requests>=2.19.0 in c:\users\stefan\anaconda3\lib\site-packages (from datasets<2.0.0,>=1.13.3->pysentimiento) (2.25.1)
# Collecting dill
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
# Requirement already satisfied: pyyaml in c:\users\stefan\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets<2.0.0,>=1.13.3->pysentimiento) (5.4.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\stefan\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets<2.0.0,>=1.13.3->pysentimiento) (3.7.4.3)
# Requirement already satisfied: filelock in c:\users\stefan\anaconda3\lib\site-packages (from huggingface-hub<1.0.0,>=0.1.0->datasets<2.0.0,>=1.13.3->pysentimiento) (3.0.12)
# Requirement already satisfied: pyparsing>=2.0.2 in c:\users\stefan\anaconda3\lib\site-packages (from packaging->datasets<2.0.0,>=1.13.3->pysentimiento) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\stefan\anaconda3\lib\site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\stefan\anaconda3\lib\site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in c:\users\stefan\anaconda3\lib\site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (4.0.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\stefan\anaconda3\lib\site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.13.3->pysentimiento) (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\stefan\anaconda3\lib\site-packages (from sklearn<0.1,>=0.0->pysentimiento) (0.24.1)
# Requirement already satisfied: colorama in c:\users\stefan\anaconda3\lib\site-packages (from tqdm>=4.62.1->datasets<2.0.0,>=1.13.3->pysentimiento) (0.4.4)
# Collecting sacremoses
#   Downloading sacremoses-0.0.49-py3-none-any.whl (895 kB)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\stefan\anaconda3\lib\site-packages (from transformers<5.0.0,>=4.11.3->pysentimiento) (2021.4.4)
# Collecting tokenizers!=0.11.3,>=0.11.1
#   Downloading tokenizers-0.11.6-cp38-cp38-win_amd64.whl (3.2 MB)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp38-cp38-win_amd64.whl (122 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp38-cp38-win_amd64.whl (28 kB)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp38-cp38-win_amd64.whl (33 kB)
# Collecting charset-normalizer<3.0,>=2.0
#   Downloading charset_normalizer-2.0.12-py3-none-any.whl (39 kB)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\stefan\anaconda3\lib\site-packages (from aiohttp->datasets<2.0.0,>=1.13.3->pysentimiento) (20.3.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in c:\users\stefan\anaconda3\lib\site-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in c:\users\stefan\anaconda3\lib\site-packages (from pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (2021.1)
# Requirement already satisfied: six>=1.5 in c:\users\stefan\anaconda3\lib\site-packages (from python-dateutil>=2.7.3->pandas->datasets<2.0.0,>=1.13.3->pysentimiento) (1.15.0)
# Requirement already satisfied: joblib in c:\users\stefan\anaconda3\lib\site-packages (from sacremoses->transformers<5.0.0,>=4.11.3->pysentimiento) (1.0.1)
# Requirement already satisfied: click in c:\users\stefan\anaconda3\lib\site-packages (from sacremoses->transformers<5.0.0,>=4.11.3->pysentimiento) (7.1.2)
# Requirement already satisfied: scipy>=0.19.1 in c:\users\stefan\anaconda3\lib\site-packages (from scikit-learn->sklearn<0.1,>=0.0->pysentimiento) (1.6.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\stefan\anaconda3\lib\site-packages (from scikit-learn->sklearn<0.1,>=0.0->pysentimiento) (2.1.0)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1316 sha256=0e21ee70863762d47f31d60135d9e69be1e9f0cc8715a2b452f72131fa964993
#   Stored in directory: c:\users\stefan\appdata\local\pip\cache\wheels\22\0b\40\fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# Installing collected packages: multidict, frozenlist, yarl, charset-normalizer, async-timeout, aiosignal, tqdm, fsspec, dill, aiohttp, xxhash, tokenizers, sacremoses, responses, pyarrow, multiprocess, huggingface-hub, transformers, torch, sklearn, datasets, pysentimiento
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.59.0
#     Uninstalling tqdm-4.59.0:
#       Successfully uninstalled tqdm-4.59.0
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 0.9.0
#     Uninstalling fsspec-0.9.0:
#       Successfully uninstalled fsspec-0.9.0
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 charset-normalizer-2.0.12 datasets-1.18.4 dill-0.3.4 frozenlist-1.3.0 fsspec-2022.2.0 huggingface-hub-0.4.0 multidict-6.0.2 multiprocess-0.70.12.2 pyarrow-7.0.0 pysentimiento-0.3.2 responses-0.18.0 sacremoses-0.0.49 sklearn-0.0 tokenizers-0.11.6 torch-1.11.0 tqdm-4.63.1 transformers-4.17.0 xxhash-3.0.0 yarl-1.7.2

# %%
df_1=pd.read_csv("all_tweets_sentiment_1.csv")

# %%
df_1['cleaned_text'] = df_1['cleaned_text'].astype(str)

# %%
df_1['text'] = df_1['text'].astype(str)

# %%
pd.set_option('display.max_rows', 100)

# %%
print(df_1["Days since"].value_counts()) #0,5,-5,195
# Out:
#  3      21717
#  1      21370
#  5      21041
#  6      20844
#  2      20498
#  4      20119
#  7      19443
#  8      18480
#  28     17554
#  10     15879
#  12     15832
#  26     15607
#  11     15374
#  9      14955
#  25     14847
#  0      14545
#  20     14430
#  18     13976
#  21     13781
#  27     13710
#  22     13112
#  23     12935
#  29     12496
#  19     12398
#  24     12233
#  13     12064
#  17     12043
#  15     11869
#  14     11737
#  208    11600
#  16     11366
#  209    10985
#  210    10815
#  183    10642
#  212    10312
#  211    10173
#  203    10116
# -17     10085
#  185    10053
#  189    10042
#  184     9963
#  196     9962
#  202     9749
#  198     9714
# -22      9675
# -1       9633
#  195     9607
#  194     9448
# -21      9374
#  186     9369
# -2       9328
#  201     9320
#  207     9320
#  197     9297
# -23      9158
#  188     9132
# -16      9126
# -9       9055
#  193     8975
#  204     8952
#  187     8849
# -14      8845
# -8       8810
# -3       8807
# -7       8803
#  205     8724
# -15      8646
#  191     8550
#  200     8541
# -13      8529
# -20      8404
#  190     8391
#  192     8385
#  199     8373
# -10      8345
# -12      8151
# -6       7890
#  206     7863
# -19      7834
# -24      7808
# -5       7785
# -18      7704
# -11      7413
# -4       7272
# -25      6841
# -29      6649
# -30      6595
# -28      6557
#  30      6444
# -27      6345
# -26      5541
# -31      3835
#  213     2884
# Name: Days since, dtype: int64

# %%
#Filter on four days for analysis
df_test=df_1[df_1["Days since"].isin([-5,0,5,195])]

# %%
df_test["Days since"].value_counts()
# Out:
#  5      21041
#  0      14545
#  195     9607
# -5       7785
# Name: Days since, dtype: int64

# %%
from pysentimiento import create_analyzer
from pysentimiento.preprocessing import preprocess_tweet

# %%
import time

# %%
#Without preprocessing
def get_sentiment_np(data,column):
    start_time = time.time()
    negative=[]
    analyzer = create_analyzer(task="sentiment", lang="es")
    for index, row in data.iterrows():
        score=analyzer.predict(row[column])
        neg=score.probas["NEG"]
        negative.append(neg)
    data["sentiment_neg"]=negative
    print("--- %s seconds ---" % (time.time() - start_time))
    return data

# %%
df_test=get_sentiment_np(df_test,"cleaned_text")
# Out:
# Downloading:   0%|          | 0.00/334 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/838k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/925 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/415M [00:00<?, ?B/s]
# --- 7360.887239694595 seconds ---

# %%
df_test.to_csv('subset_sentiment.csv')

# %%
df_test.groupby(["Country","Categorie","Days since"])["sentiment_neg"].mean()
# Out:
# Country   Categorie   Days since
# Chile     Celebrity   -5            0.271262
#                        0            0.353864
#                        5            0.378083
#                        195          0.290048
#           Politician  -5            0.214412
#                        0            0.398124
#                        5            0.365078
#                        195          0.290490
# Colombia  Celebrity   -5            0.298355
#                        0            0.367702
#                        5            0.403198
#                        195          0.265793
#           Politician  -5            0.346449
#                        0            0.446477
#                        5            0.429534
#                        195          0.290992
# Name: sentiment_neg, dtype: float64

# %%
pd.options.display.max_colwidth = 500

# %%
df_2[df_2["sentiment_neg"]<0.05]["text"]
# Out:
# 4                                            #FelizSábado no olvidemos que esta semana tuvimos un avance histórico. Espero que los que hoy tratan de instalar la posverdad dejen las pequeñeces de lado y aporten en construir una #NuevaConstitucionParaChile. O se quedarán con la del 80? https://t.co/s0Hof8wYWd
# 7         Buena nueva! Acabamos de ampliar la capacidad crediticia del Banco Estado a través de un aumento de capital. Esta acción permite ampliar la capacidad crediticia y contrarresta la tendencia decreciente de sus límites normativos de capital. Esto servirá de apoyo para MIPYMES. https://t.co/aCWtoVQKjZ
# 8                           Una #NuevaConstitucionParaChile es el primer paso para recuperar nuestra dignidad. Chile despertó y lo logró. Ahora a preparar un plebiscito impecable para que la propuesta de Asamblea Constituyente - 100% ciudadana - gane y defina la forma en que construiremos nuestra nueva casa
# 9     Han sido días durísimos, pero hoy damos un tremendo paso que ensancha la democracia. Gracias a ustedes tendremos un #PlebiscitoNuevaConstitucion donde tod/s podremos elegir la forma en que queremos que se redacte y quienes nos representaran para ello. Un madrugada de felicidad! https://t.co/qa4yN2qEkt
# 12                                 Sólo un plebiscito garantizará cual es la opción que prefiere la ciudadanía para redactar una #NuevaConstitución. Algun/s marcaran #AC y otr/s #ConvenciónConstituyente. Buena noticia que se sumen nuevas voces a esta propuesta. Que todo Chile decida. https://t.co/vcDsyc57zy
# 17    14 movimientos políticos hemos dicho q una #NuevaConstitución debe resolverlo el pueblo de Chile de manera democrática a través de un #PlebiscitoConstituyente. Pero vamos más allá y decimos q nuestra opción en ese plebiscito es #AsambleaConstituyente a través delegados electos. https://t.co/YVTJ6zVaUU
# 21                              Que la ciudadania sea la que decida, que la ciudadania valide cual es la mejor forma de redactar una #NuevaConstitución. Eso es lo que se escucha en la calle. Buen paso del Gobierno, pero debe ser sin miedo. \n\n#FelizLunes\n#AsambleaConstituyenteoNADA https://t.co/1M3E9ikUyU
# 22                                                                                                                                                              Presidente @sebastianpinera, más vale tarde que nunca. Escuche a la gente. A su gente. #MarchaMasGrandeDeChile3 #FelizSabado https://t.co/xqFrv6PGXn
# 23                                                                                                                                                                                   @Julio75436478 Julio, entiendo que la investigación está siendo llevado por Fiscalía. En cuanto me enteré solicité información.
# 24                                                                                                                        @estranged1977 @Carabdechile @PDI_CHILE @sebastianpinera Repudio completamente ese acto, pero me podrías entregar los antecedentes sobre el partido del FA al que pertenece. Quedo atento.
# 26         En Comisión Investigadora por Crisis del Agua en #Osorno consulté a representantes de @Corfo sobre subsidios de apoyo a la PYME. Se nos aclaró que no se han solicitado recursos de apoyo y que existe voluntad de financiarlos en caso de ser presentados. Sería bueno pedirlos! https://t.co/rexdpC05iC
# 28                                                                                                                                                                                                                                  Aguante estimado @Manuel_Barria! Admirable como siempre. https://t.co/EQHAh4h7EN
# Name: text, dtype: object

# %%
def get_hate_speech(data,column):
    hate=[]
    hate_speech_analyzer = create_analyzer(task="hate_speech", lang="es")
    for index, row in data.iterrows():
        text=preprocess_tweet(row[column])
        score=hate_speech_analyzer.predict(text)
        ha_score=(score.probas["hateful"]+score.probas["aggressive"])/2
        hate.append(ha_score)
    data["hate_speech"]=hate
    return data

# %%
df_test=get_hate_speech(df_test,"text")
df_test.to_csv('subset_sentiment.csv')
# Out:
# https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmp3szmjucn
# Downloading:   0%|          | 0.00/334 [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer_config.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\f151cdb0362e2cc8c419bd5878232bea313009ac93445c0f66bf43ea764cd71c.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\f151cdb0362e2cc8c419bd5878232bea313009ac93445c0f66bf43ea764cd71c.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpak4ixxo2
# Downloading:   0%|          | 0.00/838k [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\82bf0643b37bd3be5cb16b6646358a7e6c7de8829f035e79cdc14ad408ebf3ce.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\82bf0643b37bd3be5cb16b6646358a7e6c7de8829f035e79cdc14ad408ebf3ce.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpxumtpipm
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/special_tokens_map.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\29bbf6eb913fdd3d8aaabeec43896b21a574167c27d3a9a85fc9dc57eea39ace.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\29bbf6eb913fdd3d8aaabeec43896b21a574167c27d3a9a85fc9dc57eea39ace.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\82bf0643b37bd3be5cb16b6646358a7e6c7de8829f035e79cdc14ad408ebf3ce.0843b07596b388e054bae078721182b4846b9e28a7bbf04d7079b274f8613ae3
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/added_tokens.json from cache at None
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/special_tokens_map.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\29bbf6eb913fdd3d8aaabeec43896b21a574167c27d3a9a85fc9dc57eea39ace.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/tokenizer_config.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\f151cdb0362e2cc8c419bd5878232bea313009ac93445c0f66bf43ea764cd71c.50a2bcf7668df2ff5a82b7b0455533bb4c0db21e6e33565fa20fd7dc8a3be740
# https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/config.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmprs1sci5n
# Downloading:   0%|          | 0.00/956 [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/config.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\c798fcd43b0ff166a11ccb606e916eed37ea5800b4dd20ff2edd880fdb8a5cbd.29b427f0b44d35a50b9f730f9e93dbf914ed3fb60537c82b311e1f4732dfdcca
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\c798fcd43b0ff166a11ccb606e916eed37ea5800b4dd20ff2edd880fdb8a5cbd.29b427f0b44d35a50b9f730f9e93dbf914ed3fb60537c82b311e1f4732dfdcca
# loading configuration file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/config.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\c798fcd43b0ff166a11ccb606e916eed37ea5800b4dd20ff2edd880fdb8a5cbd.29b427f0b44d35a50b9f730f9e93dbf914ed3fb60537c82b311e1f4732dfdcca
# Model config RobertaConfig {
#   "_name_or_path": "pysentimiento/robertuito-hate-speech",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "hateful",
#     "1": "targeted",
#     "2": "aggressive"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "aggressive": 2,
#     "hateful": 0,
#     "targeted": 1
#   },
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "problem_type": "multi_label_classification",
#   "torch_dtype": "float32",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 30002
# }
#
# https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmp3r44ss2_
# Downloading:   0%|          | 0.00/415M [00:00<?, ?B/s]
# storing https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/pytorch_model.bin in cache at C:\Users\Stefan/.cache\huggingface\transformers\0f783b30471b13a04879e5c7f59ffb7e46b2aa6070bfc1de054e22f3730876b4.55428a0f24699e85f25e62ebe82b655dc72cfe0abf1f37e9b20c3d41978bbcf0
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\0f783b30471b13a04879e5c7f59ffb7e46b2aa6070bfc1de054e22f3730876b4.55428a0f24699e85f25e62ebe82b655dc72cfe0abf1f37e9b20c3d41978bbcf0
# loading weights file https://huggingface.co/pysentimiento/robertuito-hate-speech/resolve/main/pytorch_model.bin from cache at C:\Users\Stefan/.cache\huggingface\transformers\0f783b30471b13a04879e5c7f59ffb7e46b2aa6070bfc1de054e22f3730876b4.55428a0f24699e85f25e62ebe82b655dc72cfe0abf1f37e9b20c3d41978bbcf0
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at pysentimiento/robertuito-hate-speech.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
df_test.groupby(["Country","Categorie","Days since"])["hate_speech"].mean()
# Out:
# Country   Categorie   Days since
# Chile     Celebrity   -5            0.057768
#                        0            0.075819
#                        5            0.074820
#                        195          0.058602
#           Politician  -5            0.041175
#                        0            0.079462
#                        5            0.071159
#                        195          0.051063
# Colombia  Celebrity   -5            0.052282
#                        0            0.077315
#                        5            0.071653
#                        195          0.052143
#           Politician  -5            0.059649
#                        0            0.074685
#                        5            0.076306
#                        195          0.048112
# Name: hate_speech, dtype: float64

# %%
df_test["hate_speech"]
# Out:
# 70         0.016624
# 71         0.033502
# 72         0.015076
# 73         0.034729
# 74         0.037777
#              ...
# 1009210    0.013698
# 1009211    0.097489
# 1009263    0.153460
# 1009264    0.011650
# 1009265    0.553313
# Name: hate_speech, Length: 52978, dtype: float64

# %%
def get_emotions(data,column):
    
    emotions=["fear","surprise","joy","disgust","sadness","anger","others"]
    fear=[]
    surprise=[]
    joy=[]
    disgust=[]
    sadness=[]
    anger=[]
    others=[]
    
    emotion_analyzer = create_analyzer(task="emotion", lang="en")
    for index, row in data.iterrows():
        text=preprocess_tweet(row[column])
        score=emotion_analyzer.predict(text)
        fear.append(score.probas["fear"])
        surprise.append(score.probas["surprise"])
        joy.append(score.probas["joy"])
        disgust.append(score.probas["disgust"])
        sadness.append(score.probas["sadness"])
        anger.append(score.probas["anger"])
        others.append(score.probas["others"])
        
    data['fear']=fear
    data['surprise']=surprise
    data['joy']=joy
    data['disgust']=disgust
    data['sadness']=sadness
    data['anger']=anger
    data['others']=others
    
    return data

# %%
df_test=get_emotions(df_test,"text")
df_test.to_csv('subset_sentiment.csv')
# Out:
# https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/tokenizer_config.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpr6l64n3u
# Downloading:   0%|          | 0.00/295 [00:00<?, ?B/s]
# storing https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/tokenizer_config.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\1740697312c59fe96586f476c7765cd6f08516a6102ea96f22ffee64f7553234.c260b44e952f7f2a825aac395f2ebbed4ac9553800d1e320af246e81a548f37c
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\1740697312c59fe96586f476c7765cd6f08516a6102ea96f22ffee64f7553234.c260b44e952f7f2a825aac395f2ebbed4ac9553800d1e320af246e81a548f37c
# https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmp15mnf5yq
# Downloading:   0%|          | 0.00/999 [00:00<?, ?B/s]
# storing https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# loading configuration file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# Model config RobertaConfig {
#   "_name_or_path": "finiteautomata/bertweet-base-emotion-analysis",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "others",
#     "1": "joy",
#     "2": "sadness",
#     "3": "anger",
#     "4": "surprise",
#     "5": "disgust",
#     "6": "fear"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "anger": 3,
#     "disgust": 5,
#     "fear": 6,
#     "joy": 1,
#     "others": 0,
#     "sadness": 2,
#     "surprise": 4
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/vocab.txt not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpbkg7d816
# Downloading:   0%|          | 0.00/824k [00:00<?, ?B/s]
# storing https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/vocab.txt in cache at C:\Users\Stefan/.cache\huggingface\transformers\b7837213513a9f3852dcb04048f70c13cbd0590be030e534734ffd42cbdcf45a.f8a4dfe5c3c45a26f9df849d732decb191dc0c05ab270799695430332d143982
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\b7837213513a9f3852dcb04048f70c13cbd0590be030e534734ffd42cbdcf45a.f8a4dfe5c3c45a26f9df849d732decb191dc0c05ab270799695430332d143982
# https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/bpe.codes not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpavf0comq
# Downloading:   0%|          | 0.00/1.03M [00:00<?, ?B/s]
# storing https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/bpe.codes in cache at C:\Users\Stefan/.cache\huggingface\transformers\76e357e2554ebe053d1c4c613506bc2cc19d66ae27fec8218261a7f73c6456b9.75877d86011e5d5d46614d3a21757b705e9d20ed45a019805d25159b4837b0a4
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\76e357e2554ebe053d1c4c613506bc2cc19d66ae27fec8218261a7f73c6456b9.75877d86011e5d5d46614d3a21757b705e9d20ed45a019805d25159b4837b0a4
# https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/added_tokens.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpony0ckck
# Downloading:   0%|          | 0.00/17.0 [00:00<?, ?B/s]
# storing https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/added_tokens.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\c4b7522f44ed8adb95e62288c6458da591654f7466e3ce2f9c730bb4087411d2.c1e7052e39d2135302ec27455f6db22e1520e6539942ff60a849c7f83f8ec6dc
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\c4b7522f44ed8adb95e62288c6458da591654f7466e3ce2f9c730bb4087411d2.c1e7052e39d2135302ec27455f6db22e1520e6539942ff60a849c7f83f8ec6dc
# https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/special_tokens_map.json not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpefyt8b2c
# Downloading:   0%|          | 0.00/150 [00:00<?, ?B/s]
# storing https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/special_tokens_map.json in cache at C:\Users\Stefan/.cache\huggingface\transformers\01581144d9bf96cb9c7d8a77ee93c8b1f1095af5c1204b1b038a8cb0e3247aa8.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\01581144d9bf96cb9c7d8a77ee93c8b1f1095af5c1204b1b038a8cb0e3247aa8.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/vocab.txt from cache at C:\Users\Stefan/.cache\huggingface\transformers\b7837213513a9f3852dcb04048f70c13cbd0590be030e534734ffd42cbdcf45a.f8a4dfe5c3c45a26f9df849d732decb191dc0c05ab270799695430332d143982
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/bpe.codes from cache at C:\Users\Stefan/.cache\huggingface\transformers\76e357e2554ebe053d1c4c613506bc2cc19d66ae27fec8218261a7f73c6456b9.75877d86011e5d5d46614d3a21757b705e9d20ed45a019805d25159b4837b0a4
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/added_tokens.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\c4b7522f44ed8adb95e62288c6458da591654f7466e3ce2f9c730bb4087411d2.c1e7052e39d2135302ec27455f6db22e1520e6539942ff60a849c7f83f8ec6dc
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/special_tokens_map.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\01581144d9bf96cb9c7d8a77ee93c8b1f1095af5c1204b1b038a8cb0e3247aa8.0dc5b1041f62041ebbd23b1297f2f573769d5c97d8b7c28180ec86b8f6185aa8
# loading file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/tokenizer_config.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\1740697312c59fe96586f476c7765cd6f08516a6102ea96f22ffee64f7553234.c260b44e952f7f2a825aac395f2ebbed4ac9553800d1e320af246e81a548f37c
# loading configuration file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# Model config RobertaConfig {
#   "_name_or_path": "finiteautomata/bertweet-base-emotion-analysis",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "others",
#     "1": "joy",
#     "2": "sadness",
#     "3": "anger",
#     "4": "surprise",
#     "5": "disgust",
#     "6": "fear"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "anger": 3,
#     "disgust": 5,
#     "fear": 6,
#     "joy": 1,
#     "others": 0,
#     "sadness": 2,
#     "surprise": 4
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# Adding <mask> to the vocabulary
# loading configuration file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/config.json from cache at C:\Users\Stefan/.cache\huggingface\transformers\c246eed05359b1a49c45955b0265b488e35b0cbd2628e3ead7dd54c8815162ee.a2dff24b4e0a884c6d58a09968c5b68e7391e749eb698ad92541818d420fd01b
# Model config RobertaConfig {
#   "_name_or_path": "finiteautomata/bertweet-base-emotion-analysis",
#   "architectures": [
#     "RobertaForSequenceClassification"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "bos_token_id": 0,
#   "classifier_dropout": null,
#   "eos_token_id": 2,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "id2label": {
#     "0": "others",
#     "1": "joy",
#     "2": "sadness",
#     "3": "anger",
#     "4": "surprise",
#     "5": "disgust",
#     "6": "fear"
#   },
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "label2id": {
#     "anger": 3,
#     "disgust": 5,
#     "fear": 6,
#     "joy": 1,
#     "others": 0,
#     "sadness": 2,
#     "surprise": 4
#   },
#   "layer_norm_eps": 1e-05,
#   "max_position_embeddings": 130,
#   "model_type": "roberta",
#   "num_attention_heads": 12,
#   "num_hidden_layers": 12,
#   "pad_token_id": 1,
#   "position_embedding_type": "absolute",
#   "tokenizer_class": "BertweetTokenizer",
#   "transformers_version": "4.17.0",
#   "type_vocab_size": 1,
#   "use_cache": true,
#   "vocab_size": 64001
# }
#
# https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/pytorch_model.bin not found in cache or force_download set to True, downloading to C:\Users\Stefan\.cache\huggingface\transformers\tmpwqie_38b
# Downloading:   0%|          | 0.00/515M [00:00<?, ?B/s]
# storing https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/pytorch_model.bin in cache at C:\Users\Stefan/.cache\huggingface\transformers\61c5894a0aca5ed63159e2ec6a5501db48124c1e6de287b82bc634334f031203.9c3c4c16d0dd174434d42471b9d4670734d982be506a06fc3111c12bee4380c7
# creating metadata file for C:\Users\Stefan/.cache\huggingface\transformers\61c5894a0aca5ed63159e2ec6a5501db48124c1e6de287b82bc634334f031203.9c3c4c16d0dd174434d42471b9d4670734d982be506a06fc3111c12bee4380c7
# loading weights file https://huggingface.co/finiteautomata/bertweet-base-emotion-analysis/resolve/main/pytorch_model.bin from cache at C:\Users\Stefan/.cache\huggingface\transformers\61c5894a0aca5ed63159e2ec6a5501db48124c1e6de287b82bc634334f031203.9c3c4c16d0dd174434d42471b9d4670734d982be506a06fc3111c12bee4380c7
# All model checkpoint weights were used when initializing RobertaForSequenceClassification.
#
# All the weights of RobertaForSequenceClassification were initialized from the model checkpoint at finiteautomata/bertweet-base-emotion-analysis.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use RobertaForSequenceClassification for predictions without further training.
# PyTorch: setting up devices
# The default value for the training argument `--report_to` will change in v5 (from all installed integrations to none). In v5, you will need to use `--report_to all` to get the same behavior as now. You should start updating your code and make this info disappear :-).

# %%
df_test.groupby(["Country","Categorie","Days since"])[["sadness","joy","fear","disgust","anger","surprise","others"]].mean()
# Out:
#                                  sadness       joy      fear   disgust  \
# Country  Categorie  Days since
# Chile    Celebrity  -5          0.006652  0.087852  0.003976  0.018744
#                      0          0.004152  0.063901  0.003150  0.021236
#                      5          0.005314  0.043536  0.003091  0.029715
#                      195        0.004774  0.081065  0.003585  0.017331
#          Politician -5          0.005591  0.129671  0.001799  0.016863
#                      0          0.002287  0.062745  0.002133  0.045632
#                      5          0.002524  0.053415  0.002322  0.043821
#                      195        0.006569  0.048037  0.002211  0.019814
# Colombia Celebrity  -5          0.004483  0.081021  0.003066  0.018916
#                      0          0.004974  0.058259  0.003533  0.026025
#                      5          0.004294  0.057024  0.002934  0.029738
#                      195        0.003787  0.090553  0.002640  0.016869
#          Politician -5          0.003813  0.050108  0.002670  0.024581
#                      0          0.009379  0.026845  0.002247  0.035072
#                      5          0.004253  0.037297  0.003179  0.037656
#                      195        0.005354  0.092795  0.002217  0.026012
#
#                                    anger  surprise    others
# Country  Categorie  Days since
# Chile    Celebrity  -5          0.008362  0.004013  0.870401
#                      0          0.009404  0.004104  0.894054
#                      5          0.017935  0.003490  0.896918
#                      195        0.006359  0.003975  0.882911
#          Politician -5          0.010305  0.002239  0.833532
#                      0          0.013442  0.002257  0.871503
#                      5          0.031129  0.002358  0.864431
#                      195        0.005904  0.002136  0.915329
# Colombia Celebrity  -5          0.006831  0.003089  0.882594
#                      0          0.009520  0.002706  0.894984
#                      5          0.010167  0.002737  0.893106
#                      195        0.006817  0.003409  0.875924
#          Politician -5          0.004807  0.002245  0.911776
#                      0          0.017155  0.002223  0.907079
#                      5          0.013414  0.002136  0.902064
#                      195        0.006063  0.002228  0.865331

# %% [markdown]
# **Analyze Data**

# %%
sentiment=pd.read_csv("C:/Users/Stefan Hoeller/Documents/BSE/TextMining/FinalProjectTextMining/Data/subset_sentiment.csv")

# %%
sentiment.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52978 entries, 0 to 52977
# Data columns (total 42 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Unnamed: 0.2                           52978 non-null  int64
#  1   Unnamed: 0                             52978 non-null  int64
#  2   Unnamed: 0.1                           52978 non-null  int64
#  3   level_0                                52978 non-null  int64
#  4   index                                  51710 non-null  float64
#  5   Unnamed: 0.1.1                         51710 non-null  float64
#  6   id                                     52978 non-null  int64
#  7   author_id                              52978 non-null  int64
#  8   created_at                             52978 non-null  object
#  9   text                                   52978 non-null  object
#  10  public_metrics.like_count              52978 non-null  int64
#  11  public_metrics.quote_count             52978 non-null  int64
#  12  public_metrics.reply_count             52978 non-null  int64
#  13  public_metrics.retweet_count           52978 non-null  int64
#  14  author.username                        52978 non-null  object
#  15  Country                                52978 non-null  object
#  16  Categorie                              52978 non-null  object
#  17  Time                                   52978 non-null  object
#  18  Left/Right                             6041 non-null   object
#  19  author.entities.description.hashtags   12929 non-null  object
#  20  author.public_metrics.following_count  52978 non-null  int64
#  21  in_reply_to_user_id                    11352 non-null  float64
#  22  retweeted_user_id                      25571 non-null  float64
#  23  quoted_user_id                         4233 non-null   float64
#  24  author.name                            52978 non-null  object
#  25  author.description                     52154 non-null  object
#  26  possibly_sensitive                     52978 non-null  bool
#  27  Date                                   52978 non-null  object
#  28  Day Protest                            52978 non-null  object
#  29  Days since                             52978 non-null  int64
#  30  cleaned_text                           49734 non-null  object
#  31  stem_text                              49734 non-null  object
#  32  sentiment                              52978 non-null  float64
#  33  sentiment_neg                          52978 non-null  float64
#  34  hate_speech                            52978 non-null  float64
#  35  fear                                   52978 non-null  float64
#  36  surprise                               52978 non-null  float64
#  37  joy                                    52978 non-null  float64
#  38  disgust                                52978 non-null  float64
#  39  sadness                                52978 non-null  float64
#  40  anger                                  52978 non-null  float64
#  41  others                                 52978 non-null  float64
# dtypes: bool(1), float64(15), int64(12), object(14)
# memory usage: 16.6+ MB

# %%
sns.color_palette("icefire", as_cmap=True)
sns.set_palette("icefire")

# %%
# set as Categorical and Categories as strings
sentiment.sort_values('Days since', inplace=True, ascending=True)
sentiment["Timeline"] = sentiment["Days since"].astype(str)


# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='sentiment_neg', data=sentiment, hue='Country')

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='sentiment_neg', data=sentiment, hue='Country',style="Categorie")

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='sentiment_neg', data=sentiment, hue='Country',style="Left/Right")

# %%
plot = sns.factorplot(x='Country', y='sentiment_neg', hue='Timeline', data=sentiment, kind='bar')
#plot.set_ylabel( "Negativity of the Tweet")
plot.set(xlabel='Country', ylabel='Negativity of the Tweet')

# %%
g = sns.FacetGrid(sentiment, row="Country", col="Categorie", hue="Timeline", height=5,aspect=1)
g.map(sns.barplot, "Timeline", "sentiment_neg",order=["-5", "0","5","195"])
g.add_legend()

# %% [markdown]
# **Hatespeech**

# %%
# plot disgust, anger, sadness, joy
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='disgust', data=sentiment, hue='Country')

# %%
# plot
fig, ax = plt.subplots(figsize = (10,5))
p1 = sns.lineplot(ax=ax, x='Timeline', y='hate_speech', data=sentiment, hue='Country',style="Categorie")
p1.set_ylabel("% of Tweets that contain Hate Speech")
# Out:
# Text(0, 0.5, '% of Tweets that contain Hate Speech')

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='hate_speech', data=sentiment, hue='Country',style="Left/Right")

# %% [markdown]
# **Emotions**

# %%
chile_sent=sentiment[sentiment["Country"]=="Chile"]
col_sent=sentiment[sentiment["Country"]=="Colombia"]

# %%
plot = sns.factorplot(x='Country', y='sentiment_neg', hue='Timeline', data=chile_sent, kind='bar')
#plot.set_ylabel( "Negativity of the Tweet")
plot.set(xlabel='Country', ylabel='Negativity of the Tweet')

# %%
g = sns.FacetGrid(sentiment, row="Country", col="Categorie", hue="Timeline", height=5,aspect=1)
g.map(sns.barplot, "Timeline", "sentiment_neg",order=["-5", "0","5","195"])
g.add_legend()

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='disgust', data=chile_sent, color='red')
p1 = sns.lineplot(ax=ax, x='Timeline', y='anger', data=chile_sent, color='blue')
p1 = sns.lineplot(ax=ax, x='Timeline', y='sadness', data=chile_sent, color='green")
p1 = sns.lineplot(ax=ax, x='Timeline', y='joy', data=chile_sent, color='black')
# Out:
#   Input In [105]
#     p1 = sns.lineplot(ax=ax, x='Timeline', y='sadness', data=chile_sent, color='green")
#                                                                                        ^
# SyntaxError: EOL while scanning string literal

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='disgust', data=col_sent, color='red')
p1 = sns.lineplot(ax=ax, x='Timeline', y='anger', data=col_sent, color='blue')
p1 = sns.lineplot(ax=ax, x='Timeline', y='sadness', data=col_sent, color='green')
p1 = sns.lineplot(ax=ax, x='Timeline', y='joy', data=col_sent, color='black')

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='disgust', data=col_sent, color='red',style="Left/Right")
p1 = sns.lineplot(ax=ax, x='Timeline', y='anger', data=col_sent, color='blue',style="Left/Right")
p1 = sns.lineplot(ax=ax, x='Timeline', y='sadness', data=col_sent, color='green',style="Left/Right")
p1 = sns.lineplot(ax=ax, x='Timeline', y='joy', data=col_sent, color='black',style="Left/Right")

# %%
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='disgust', data=chile_sent, color='red',style="Left/Right")
p1 = sns.lineplot(ax=ax, x='Timeline', y='anger', data=chile_sent, color='blue',style="Left/Right")
p1 = sns.lineplot(ax=ax, x='Timeline', y='sadness', data=chile_sent, color='green',style="Left/Right")
p1 = sns.lineplot(ax=ax, x='Timeline', y='joy', data=chile_sent, color='black',style="Left/Right")

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='disgust', data=col_sent, color='red',style="Categorie")
p1 = sns.lineplot(ax=ax, x='Timeline', y='anger', data=col_sent, color='blue',style="Categorie")
p1 = sns.lineplot(ax=ax, x='Timeline', y='sadness', data=col_sent, color='green',style="Categorie")
p1 = sns.lineplot(ax=ax, x='Timeline', y='joy', data=col_sent, color='black',style="Categorie")

# %%
# plot
fig, ax = plt.subplots(figsize = (16,8))
p1 = sns.lineplot(ax=ax, x='Timeline', y='disgust', data=chile_sent, color='red',style="Categorie")
p1 = sns.lineplot(ax=ax, x='Timeline', y='anger', data=chile_sent, color='blue',style="Categorie")
p1 = sns.lineplot(ax=ax, x='Timeline', y='sadness', data=chile_sent, color='green',style="Categorie")
p1 = sns.lineplot(ax=ax, x='Timeline', y='joy', data=chile_sent, color='black',style="Categorie")

# %% [markdown]
# ## LDA

# %% [markdown]
# ### Unguided LDA

# %%
#Split Data
chile=df_all[df_all["Country"]=="Chile"]
colombia=df_all[df_all["Country"]=="Colombia"]

# %%
# reproducibility
seed = 42
# python RNG
import random
random.seed(seed)
# numpy RNG
import numpy as np
np.random.seed(seed)

# %%
def agg(df):
    # concatenate the string
    df['cleaned_text'] = df['cleaned_text'].astype(str)
    subset=df[['author_id','Time','cleaned_text']]

    #subset.groupby(['author_id',"Time"]).agg({'cleaned_text': ' '.join})
    df_agg=subset.groupby(['author_id',"Time"]).agg({'cleaned_text': ['. '.join, 'count']})
    df_agg.columns = df_agg.columns.droplevel(0)
    df_agg.columns=["joined_text","count_tweets"]
    return df_agg

# %% [markdown]
# **Chile Unguided**

# %%
chile_agg=agg(chile)

# %%
chile_agg
# Out:
#                                                                   joined_text  \
# author_id           Time
# 822112              After   revive el del de mayo de \n\n. envíale mis car...
#                     Before  ¡diario periodismo está disponible gracias a. ...
#                     During  jiji yaaaaaa, espero sea pronto :. muy weeeeno...
# 2312091             After   mucha fuerza marcela. mis condolencias para ti...
#                     Before  senador vota en contra de tpp- en comisión de ...
# ...                                                                       ...
# 1161468842046083073 Before  es agotador... poner el énfasis en un adolesce...
#                     During  colabora en la campaña todo irá en beneficio d...
# 1239207367105040387 After   ::. merkel destaca el valor de la prensa críti...
# 1250117104663134214 After   en serio. federico pez bonito\n+. federico pez...
# 1256746446365306882 After   se busca perito perdido paresido a una vacita....
#
#                             count_tweets
# author_id           Time
# 822112              After            188
#                     Before           108
#                     During            98
# 2312091             After            231
#                     Before           189
# ...                                  ...
# 1161468842046083073 Before           280
#                     During          1121
# 1239207367105040387 After            383
# 1250117104663134214 After            104
# 1256746446365306882 After             12
#
# [2378 rows x 2 columns]

# %%
import gensim
from gensim import models
from gensim import corpora
from gensim.utils import simple_preprocess
from collections import defaultdict

# %%
text=chile_agg['joined_text']

# %%
from termcolor import colored, cprint
from nltk.stem import SnowballStemmer   
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords

porter=SnowballStemmer("spanish")
lmtzr = WordNetLemmatizer()

stop_words = set(stopwords.words('spanish'))


def abbr_or_lower(word):
    if re.match('([A-Z]+[a-z]*){2,}', word):
        return word
    else:
        return word.lower()

def tokenize(words, modulation):
    tokens = re.split(r'\W+', words)
    stems = []
    # filter out any tokens not containing letters (e.g., numeric tokens, raw punctuation)
    for token in tokens:
        lowers=abbr_or_lower(token)
        if lowers not in stop_words:
            if re.search('[a-zA-Z]', lowers):
                if modulation==1:
                    stems.append(porter.stem(lowers))
                if modulation==2:
                    stems.append(lmtzr.lemmatize(lowers))
                if modulation==0:
                    stems.append(lowers)
                #stems.append(" ")
    return stems

# %%
texts=[tokenize(document,0) for document in text]

# %%
#making bigrams and trigrams
bigram = gensim.models.Phrases(texts, min_count=1, threshold=1)
trigram = gensim.models.Phrases(bigram[texts], threshold=1)  

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

texts_bigrams = [bigram_mod[doc] for doc in texts]
texts_trigrams = [trigram_mod[doc] for doc in texts]

# %%
texts=texts_trigrams


frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [
    [token for token in text if frequency[token] > 1]
    for text in texts
]

#pprint(texts)

dictionary = corpora.Dictionary(texts)
print(dictionary)

dictionary.filter_extremes(no_below = 20, no_above=0.25)
# we are getting rid of things like "said" with the no_above threshold (depending on stemming more will be thrown out)
print(dictionary)

corpus = [dictionary.doc2bow(text) for text in texts]
# Out:
# Dictionary(146557 unique tokens: ['abogada', 'abrazo_todas', 'abrazoooo', 'abrazote', 'abril']...)
# Dictionary(25037 unique tokens: ['abogada', 'abrazote', 'abril', 'abrirá', 'abrió']...)

# %%
#estimate the lda model with two topics
topicnumber=8

# Tuning: alpha='symmetric', eta=None

#alpha default is ’symmetric’: Uses a fixed symmetric prior of 1.0 / num_topics. In our case that is 0.1.
#Change alpha if wanted
lda=models.LdaModel(corpus, id2word=dictionary, num_topics=topicnumber, random_state=42,eta=0.001)

lda.print_topics(topicnumber,20)
# Out:
# [(0,
#   '0.003*"covid" + 0.002*"pandemia" + 0.002*"opinión" + 0.001*"coronavirus" + 0.001*"piñera" + 0.001*"mujeres" + 0.001*"trabajadores" + 0.001*"carabineros" + 0.001*"cuarentena" + 0.001*"derecha" + 0.001*"tras" + 0.001*"dictadura" + 0.001*"proyecto" + 0.001*"mas" + 0.001*"oposición" + 0.001*"mañalich" + 0.001*"the" + 0.001*"pueblo" + 0.001*"autoridades" + 0.001*"mujer"'),
#  (1,
#   '0.002*"piñera" + 0.001*"izquierda" + 0.001*"democracia" + 0.001*"carabineros" + 0.001*"pueblo" + 0.001*"opinión" + 0.001*"nueva_constitución" + 0.001*"constitución" + 0.001*"pandemia" + 0.001*"ny" + 0.001*"proyecto" + 0.001*"políticos" + 0.001*"dictadura" + 0.001*"mujeres" + 0.001*"mas" + 0.001*"abuela" + 0.001*"mujer" + 0.001*"diputado" + 0.001*"niños" + 0.001*"derecha"'),
#  (2,
#   '0.002*"carabineros" + 0.002*"piñera" + 0.002*"izquierda" + 0.002*"constitución" + 0.001*"nueva_constitución" + 0.001*"pueblo" + 0.001*"diputado" + 0.001*"opinión" + 0.001*"acusación_constitucional" + 0.001*"oposición" + 0.001*"derecha" + 0.001*"abuela" + 0.001*"frente_amplio" + 0.001*"democracia" + 0.001*"políticos" + 0.001*"mas" + 0.001*"ddhh" + 0.001*"ud" + 0.001*"partido" + 0.001*"ciudadanía"'),
#  (3,
#   '0.002*"abuela" + 0.002*"piñera" + 0.002*"izquierda" + 0.001*"democracia" + 0.001*"pueblo" + 0.001*"carabineros" + 0.001*"políticos" + 0.001*"ny" + 0.001*"programa" + 0.001*"derecha" + 0.001*"mas" + 0.001*"covid" + 0.001*"nueva_constitución" + 0.001*"plata" + 0.001*"quiere" + 0.001*"pc" + 0.001*"ñera" + 0.001*"opinión" + 0.001*"metro" + 0.001*"emergencia"'),
#  (4,
#   '0.002*"piñera" + 0.001*"carabineros" + 0.001*"democracia" + 0.001*"pueblo" + 0.001*"izquierda" + 0.001*"metro" + 0.001*"políticos" + 0.001*"opinión" + 0.001*"abuela" + 0.001*"agua" + 0.001*"usted" + 0.001*"mas" + 0.001*"nueva_constitución" + 0.001*"ñera" + 0.001*"ddhh" + 0.001*"paz" + 0.001*"proyecto" + 0.001*"valparaíso" + 0.001*"derecha" + 0.001*"quieren"'),
#  (5,
#   '0.001*"abuela" + 0.001*"mas" + 0.001*"piñera" + 0.001*"proyecto" + 0.001*"pueblo" + 0.001*"carabineros" + 0.001*"izquierda" + 0.001*"diputado" + 0.001*"pandemia" + 0.001*"democracia" + 0.001*"metro" + 0.001*"millones" + 0.001*"políticos" + 0.001*"oposición" + 0.001*"ud" + 0.001*"agua" + 0.001*"derecha" + 0.001*"cierto" + 0.001*"the" + 0.001*"noche"'),
#  (6,
#   '0.002*"carabineros" + 0.002*"piñera" + 0.002*"pueblo" + 0.002*"abuela" + 0.001*"democracia" + 0.001*"izquierda" + 0.001*"mujeres" + 0.001*"nueva_constitución" + 0.001*"usted" + 0.001*"mas" + 0.001*"derecha" + 0.001*"constitución" + 0.001*"ñera" + 0.001*"políticos" + 0.001*"dictadura" + 0.001*"opinión" + 0.001*"acusación_constitucional" + 0.001*"niños" + 0.001*"ddhh" + 0.001*"ciudadanía"'),
#  (7,
#   '0.002*"piñera" + 0.002*"carabineros" + 0.001*"metro" + 0.001*"opinión" + 0.001*"pueblo" + 0.001*"the" + 0.001*"izquierda" + 0.001*"cierto" + 0.001*"mas" + 0.001*"dictadura" + 0.001*"proyecto" + 0.001*"políticos" + 0.001*"necesitamos" + 0.001*"miedo" + 0.001*"ciudadanía" + 0.001*"ciudad" + 0.001*"democracia" + 0.001*"nueva_constitución" + 0.001*"paz" + 0.001*"and"')]

# %%
get_document_topics = [lda.get_document_topics(item, minimum_probability=0.000000001) for item in corpus]

#note you could also use this vector = [lda[item] for item in corpus] but it would take into account the prior

vector = [lda[item] for item in corpus]

#this produces a lits of tuples
print(get_document_topics[0:1])
print(vector[0:1])
# Out:
# [[(0, 0.13742389), (1, 0.00016273354), (2, 0.33232024), (3, 0.38702667), (4, 0.00016272996), (5, 0.0029055977), (6, 0.026455186), (7, 0.00016273321), (8, 0.11321745), (9, 0.00016273155)]]
# [[(0, 0.19532026), (2, 0.32068482), (3, 0.34823468), (6, 0.020438313), (8, 0.114145026)]]

# %% [markdown]
# **Colombia Unguided**

# %%
col_agg=agg(colombia)

# %%
text=col_agg['joined_text']

# %%
texts=[tokenize(document,0) for document in text]

# %%
#making bigrams and trigrams
bigram = gensim.models.Phrases(texts, min_count=1, threshold=1)
trigram = gensim.models.Phrases(bigram[texts], threshold=1)  

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

texts_bigrams = [bigram_mod[doc] for doc in texts]
texts_trigrams = [trigram_mod[doc] for doc in texts]

# %%
texts=texts_trigrams

frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [
    [token for token in text if frequency[token] > 1]
    for text in texts
]

#pprint(texts)

dictionary = corpora.Dictionary(texts)
print(dictionary)

dictionary.filter_extremes(no_below = 20, no_above=0.25)
# we are getting rid of things like "said" with the no_above threshold (depending on stemming more will be thrown out)
print(dictionary)

corpus = [dictionary.doc2bow(text) for text in texts]
# Out:
# Dictionary(121227 unique tokens: ['abrazo', 'abrazo_felicitaciones', 'abrazo_gigante', 'abrazo_grande', 'abrazos']...)
# Dictionary(19969 unique tokens: ['abrazo', 'abrazo_gigante', 'abrazo_grande', 'abrazos', 'abrazote']...)

# %%
#estimate the lda model with two topics
topicnumber=8

# Tuning: alpha='symmetric', eta=None

#alpha default is ’symmetric’: Uses a fixed symmetric prior of 1.0 / num_topics. In our case that is 0.1.
#Change alpha if wanted
lda=models.LdaModel(corpus, id2word=dictionary, num_topics=topicnumber, random_state=42,eta=0.001)

lda.print_topics(topicnumber,20)
# Out:
# [(0,
#   '0.002*"q" + 0.002*"duque" + 0.002*"paro" + 0.001*"the" + 0.001*"uribe" + 0.001*"petro" + 0.001*"diálogo" + 0.001*"congreso" + 0.001*"justicia" + 0.001*"fuerza_pública" + 0.001*"ón" + 0.001*"políticos" + 0.001*"medellín" + 0.001*"ciudadanos" + 0.001*"periodista" + 0.001*"guerra" + 0.001*"uribismo" + 0.001*"vivo" + 0.001*"d" + 0.001*"barranquilla"'),
#  (1,
#   '0.003*"buenas_tardes" + 0.003*"buenos_días" + 0.002*"q" + 0.001*"duque" + 0.001*"medellín" + 0.001*"paro" + 0.001*"si_posible" + 0.001*"señora" + 0.001*"of" + 0.001*"ón" + 0.001*"and" + 0.001*"petro" + 0.001*"uribe" + 0.001*"to" + 0.001*"dios" + 0.001*"the" + 0.001*"uribismo" + 0.001*"n_nel" + 0.001*"policías" + 0.001*"ciudadanos"'),
#  (2,
#   '0.002*"q" + 0.001*"duque" + 0.001*"uribe" + 0.001*"paro" + 0.001*"ciudadanos" + 0.001*"congreso" + 0.001*"the" + 0.001*"ón" + 0.001*"and" + 0.001*"fuerza_pública" + 0.001*"medellín" + 0.001*"protesta" + 0.001*"justicia" + 0.001*"d" + 0.001*"uribismo" + 0.001*"problema" + 0.001*"habla" + 0.001*"dios" + 0.001*"fútbol" + 0.001*"calles"'),
#  (3,
#   '0.002*"q" + 0.002*"the" + 0.001*"and" + 0.001*"duque" + 0.001*"uribe" + 0.001*"paro" + 0.001*"to" + 0.001*"medellín" + 0.001*"fuerza_pública" + 0.001*"of" + 0.001*"in" + 0.001*"congreso" + 0.001*"protesta" + 0.001*"uribismo" + 0.001*"ciudadanos" + 0.001*"miedo" + 0.001*"buenos_días" + 0.001*"petro" + 0.001*"manifestantes" + 0.001*"quiero"'),
#  (4,
#   '0.002*"paro" + 0.002*"duque" + 0.001*"q" + 0.001*"uribe" + 0.001*"the" + 0.001*"niños" + 0.001*"in" + 0.001*"n_nla" + 0.001*"vacunación" + 0.001*"congreso" + 0.001*"and" + 0.001*"petro" + 0.001*"social" + 0.001*"medellín" + 0.001*"muchas_gracias" + 0.001*"n_nel" + 0.001*"bloqueos" + 0.001*"ón" + 0.001*"of" + 0.001*"fuerza_pública"'),
#  (5,
#   '0.001*"duque" + 0.001*"q" + 0.001*"uribe" + 0.001*"paro" + 0.001*"barranquilla" + 0.001*"ciudadanos" + 0.001*"ón" + 0.001*"dios" + 0.001*"abril" + 0.001*"alcalde" + 0.001*"congreso" + 0.001*"mujer" + 0.001*"empresas" + 0.001*"campaña" + 0.001*"medellín" + 0.001*"justicia" + 0.001*"protesta" + 0.001*"corrupción" + 0.001*"vacunación" + 0.001*"fuerza_pública"'),
#  (6,
#   '0.002*"q" + 0.001*"uribe" + 0.001*"duque" + 0.001*"medellín" + 0.001*"the" + 0.001*"tributaria" + 0.001*"ciudadanos" + 0.001*"congreso" + 0.001*"and" + 0.001*"fuerza_pública" + 0.001*"paro" + 0.001*"justicia" + 0.001*"bloqueos" + 0.001*"diálogo" + 0.001*"dios" + 0.001*"miedo" + 0.001*"quieren" + 0.001*"fútbol" + 0.001*"barranquilla" + 0.001*"medios"'),
#  (7,
#   '0.004*"buenos_días" + 0.003*"buenas_tardes" + 0.002*"q" + 0.002*"si_posible" + 0.001*"paro" + 0.001*"buenas_noches" + 0.001*"señora" + 0.001*"fútbol" + 0.001*"medellín" + 0.001*"n_nla" + 0.001*"duque" + 0.001*"and" + 0.001*"uribe" + 0.001*"calles" + 0.001*"to" + 0.001*"the" + 0.001*"justicia" + 0.001*"petro" + 0.001*"fuerza_pública" + 0.001*"manifestantes"')]

# %% [markdown]
# Unguided LDA is not working well

# %% [markdown]
# ### Guided LDA

# %% [markdown]
# **Chile**

# %%
text=chile_agg['joined_text']

# %%
texts=[tokenize(document,1) for document in text]

# %%
#making bigrams and trigrams
bigram = gensim.models.Phrases(texts, min_count=1, threshold=1)
trigram = gensim.models.Phrases(bigram[texts], threshold=1)  

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

texts_bigrams = [bigram_mod[doc] for doc in texts]
texts_trigrams = [trigram_mod[doc] for doc in texts]

# %%
texts=texts_trigrams


frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [
    [token for token in text if frequency[token] > 1]
    for text in texts
]

#pprint(texts)

dictionary = corpora.Dictionary(texts)
print(dictionary)

dictionary.filter_extremes(no_below = 20, no_above=0.25)
# we are getting rid of things like "said" with the no_above threshold (depending on stemming more will be thrown out)
print(dictionary)

corpus = [dictionary.doc2bow(text) for text in texts]
# Out:
# Dictionary(109937 unique tokens: ['abad', 'abog', 'abraz_tod', 'abrazooo', 'abrazot']...)
# Dictionary(20664 unique tokens: ['abog', 'abraz_tod', 'abrazot', 'abri', 'abril']...)

# %%
def create_eta(priors, etadict, ntopics):
    eta = np.full(shape=(ntopics, len(etadict)), fill_value=0.0001) # create a (ntopics, nterms) matrix and fill with low number
    for word, topic in priors.items(): # for each word in the list of priors
        keyindex = [index for index,term in etadict.items() if term==word] # look up the word in the dictionary
        if (len(keyindex)>0): # if it's in the dictionary
            eta[topic,keyindex[0]] = 500  # put a large number in there
    return eta

# %%
#Input for ETA
apriori_original = {
    "policia":0,"carabinero":0,"violencia":0,"humanos":0,"protesta":0,"detención":0,"desaparecido":0,"paco":0,"quemar":0,"fuego":0,"barricada":0,"INDH":0, "represion":0, "lacrimogeno":0,
                                                 "perdigones":0, "ojo":0, "ciego":0, "mutilado":0,"ddhh":0,"dd hh":0, 'pensión':1,'AFP':1,'vejez':1,'salud':1,'fonasa':1,'consultorio':1,'hospital':1,'clínica':1,'isapre':1,'dignidad':1,'educación':1,'profesor':1,'liceo':1,'universidad':1,'gratuita':1,
                                      'sociales':1,'vivienda':1,'campamentos':1, 'delincuencia':1,
                     'corrupción':2,'soborno':2,'vendido':2,'nepotismo':2,'deshonesto':2,'ladrón':2,'robar':2,'mentir':2,
                     'metro':3,'tren':3,'pasaje':3,'transporte':3,'evadir':3,'evasión':3,'micro':3,'transantiago':3,'Hutt':3,'alza':3,'tarifa':3
}

# %%
porter=SnowballStemmer("spanish")
chile_dict_adj={}
for key, value in apriori_original.items():
    a=porter.stem(key.lower())
    chile_dict_adj[a]= value

# %%
eta = create_eta(chile_dict_adj, dictionary, 10)

# %%
topicnumber=10

#alpha default is ’symmetric’: Uses a fixed symmetric prior of 1.0 / num_topics. In our case that is 0.1.

lda=models.LdaModel(corpus, id2word=dictionary, num_topics=topicnumber, 
                    random_state=42, eta=eta, alpha='symmetric')

lda.print_topics(topicnumber,20)
# Out:
# [(0,
#   '0.006*"carabiner" + 0.005*"violenci" + 0.005*"ddhh" + 0.004*"protest" + 0.004*"represion" + 0.004*"indh" + 0.004*"pac" + 0.003*"quem" + 0.003*"ojo" + 0.003*"fueg" + 0.003*"detencion" + 0.003*"desaparec" + 0.003*"lacrimogen" + 0.003*"perdigon" + 0.003*"mutil" + 0.003*"cieg" + 0.003*"barric" + 0.003*"polici" + 0.002*"piñer" + 0.002*"izquierd"'),
#  (1,
#   '0.004*"delincuent" + 0.004*"educ" + 0.004*"afp" + 0.004*"pension" + 0.004*"dignid" + 0.004*"profesor" + 0.003*"hospital" + 0.003*"univers" + 0.003*"lice" + 0.003*"viviend" + 0.003*"isapr" + 0.003*"gratuit" + 0.003*"clinic" + 0.003*"fonas" + 0.003*"consultori" + 0.003*"campament" + 0.002*"vejez" + 0.002*"piñer" + 0.002*"d" + 0.002*"puebl"'),
#  (2,
#   '0.005*"ment" + 0.005*"rob" + 0.005*"vend" + 0.005*"corrupcion" + 0.005*"ladron" + 0.004*"deshonest" + 0.004*"soborn" + 0.004*"nepot" + 0.002*"piñer" + 0.002*"carabiner" + 0.002*"abuel" + 0.001*"congres" + 0.001*"puebl" + 0.001*"ñer" + 0.001*"acus_constitucional" + 0.001*"manifest" + 0.001*"abus" + 0.001*"peor" + 0.001*"opinion" + 0.001*"violenci"'),
#  (3,
#   '0.005*"metr" + 0.004*"transport" + 0.004*"evasion" + 0.004*"evad" + 0.004*"pasaj" + 0.003*"alza" + 0.003*"tren" + 0.003*"transantiag" + 0.003*"micr" + 0.003*"tarif" + 0.003*"hutt" + 0.001*"piñer" + 0.001*"opinion" + 0.001*"d" + 0.001*"mas" + 0.001*"abuel" + 0.001*"manifest" + 0.001*"muert" + 0.001*"puebl" + 0.001*"violenci"'),
#  (4,
#   '0.002*"izquierd" + 0.001*"violenci" + 0.001*"pandemi" + 0.001*"piñer" + 0.001*"d" + 0.001*"abuel" + 0.001*"puebl" + 0.001*"carabiner" + 0.001*"mas" + 0.001*"peor" + 0.001*"notici" + 0.001*"muert" + 0.001*"aport" + 0.001*"amor" + 0.001*"señor" + 0.001*"tv" + 0.001*"parlamentari" + 0.001*"dat" + 0.001*"maner" + 0.001*"comentari"'),
#  (5,
#   '0.002*"abuel" + 0.002*"piñer" + 0.001*"d" + 0.001*"puebl" + 0.001*"nuev_constitu" + 0.001*"izquierd" + 0.001*"muert" + 0.001*"march" + 0.001*"opinion" + 0.001*"carabiner" + 0.001*"luch" + 0.001*"cov" + 0.001*"manifest" + 0.001*"denunci" + 0.001*"democraci" + 0.001*"acus_constitucional" + 0.001*"señor" + 0.001*"car" + 0.001*"aport" + 0.001*"constitu"'),
#  (6,
#   '0.002*"piñer" + 0.002*"opinion" + 0.002*"congres" + 0.002*"nuev_constitu" + 0.001*"carabiner" + 0.001*"izquierd" + 0.001*"constitu" + 0.001*"violenci" + 0.001*"protest" + 0.001*"denunci" + 0.001*"abus" + 0.001*"puebl" + 0.001*"parlamentari" + 0.001*"democraci" + 0.001*"mas" + 0.001*"muert" + 0.001*"march" + 0.001*"d" + 0.001*"pc" + 0.001*"metr"'),
#  (7,
#   '0.002*"cov" + 0.002*"pandemi" + 0.002*"opinion" + 0.001*"mujer" + 0.001*"piñer" + 0.001*"d" + 0.001*"cuarenten" + 0.001*"coronavirus" + 0.001*"dat" + 0.001*"izquierd" + 0.001*"muert" + 0.001*"oposicion" + 0.001*"empres" + 0.001*"contagi" + 0.001*"mañalich" + 0.001*"muj" + 0.001*"carabiner" + 0.001*"denunci" + 0.001*"congres" + 0.001*"tras"'),
#  (8,
#   '0.002*"abuel" + 0.001*"argentin" + 0.001*"piñer" + 0.001*"vidal" + 0.001*"congres" + 0.001*"puebl" + 0.001*"metr" + 0.001*"march" + 0.001*"record" + 0.001*"d" + 0.001*"cuarenten" + 0.001*"u" + 0.001*"pandemi" + 0.001*"peor" + 0.001*"muert" + 0.001*"the" + 0.001*"mujer" + 0.001*"sub" + 0.001*"rt" + 0.001*"mas"'),
#  (9,
#   '0.002*"piñer" + 0.002*"abuel" + 0.002*"puebl" + 0.002*"izquierd" + 0.002*"acus_constitucional" + 0.002*"constitu" + 0.001*"congres" + 0.001*"muert" + 0.001*"d" + 0.001*"democraci" + 0.001*"carabiner" + 0.001*"mas" + 0.001*"nuev_constitu" + 0.001*"protest" + 0.001*"señor" + 0.001*"opinion" + 0.001*"violenci" + 0.001*"march" + 0.001*"firm" + 0.001*"ñer"')]

# %%
topics_chile = [lda.get_document_topics(item, minimum_probability=0.00000001) for item in corpus]

# %%
#note you could also use this vector = [lda[item] for item in corpus] but it would take into account the prior
vector = [lda[item] for item in corpus]

# %%
#this produces a lits of tuples
print(get_document_topics[0:1])
print(vector[0:1])

# %%
for topics in range(0,10):
    chile_agg["topic_"+str(topics)]=[x[topics][1] for x in topics_chile]

# %%
chile_agg=chile_agg.reset_index(level=['author_id', 'Time'])

# %%
chile_agg=chile_agg.merge(map_table[["author_id","Categorie","Left/Right","author.username"]],how="left",left_on="author_id",right_on="author_id")

# %% [markdown]
# **Human Rights are a huge deal, for the left more than the right, Social Issues are huge on politicians with the Right picking up**

# %%
sns.set()

#define plotting region (1 row, 2 columns)
fig, axes = plt.subplots(1, 4)

#create boxplot in each subplot
p1=sns.barplot(data=chile_agg,x="Time",y="topic_0",order=["Before","During","After"],hue="Categorie",ax=axes[0])
p2=sns.barplot(data=chile_agg,x="Time",y="topic_1",order=["Before","During","After"],hue="Categorie",ax=axes[1])
p3=sns.barplot(data=chile_agg,x="Time",y="topic_2",order=["Before","During","After"],hue="Categorie",ax=axes[2])
p4=sns.barplot(data=chile_agg,x="Time",y="topic_3",order=["Before","During","After"],hue="Categorie",ax=axes[3])
p1.set_ylabel("Share Human Rights Violation")
p2.set_ylabel("Share Social Issues")
p3.set_ylabel("Share Corruption")
p4.set_ylabel("Share Protest Starter")
p1.set_xlabel("Human Rights Violation")
p2.set_xlabel("Social Issues")
p3.set_xlabel("Corruption")
p4.set_xlabel("Protest Starter")
# Out:
# Text(0.5, 0, 'Protest Starter')

# %%
chile_agg.groupby(["Categorie","Time"])["topic_0"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.011815
#             Before    0.007968
#             During    0.152394
# Politician  After     0.004528
#             Before    0.012353
#             During    0.269176
# Name: topic_0, dtype: float32

# %%
chile_agg.groupby(["Categorie","Time"])["topic_1"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.017212
#             Before    0.025819
#             During    0.067854
# Politician  After     0.088792
#             Before    0.300513
#             During    0.326318
# Name: topic_1, dtype: float32

# %%
chile_agg.groupby(["Categorie","Time"])["topic_2"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.034069
#             Before    0.063854
#             During    0.049660
# Politician  After     0.000910
#             Before    0.005387
#             During    0.022084
# Name: topic_2, dtype: float32

# %%
chile_agg.groupby(["Categorie","Time"])["topic_3"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.058055
#             Before    0.115978
#             During    0.092561
# Politician  After     0.009305
#             Before    0.035548
#             During    0.006900
# Name: topic_3, dtype: float32

# %%
chile_agg.groupby(["Left/Right","Time"])["topic_0"].mean()
# Out:
# Left/Right  Time
# Left        After     0.007561
#             Before    0.004580
#             During    0.348332
# Right       After     0.001184
#             Before    0.021290
#             During    0.174664
# Name: topic_0, dtype: float32

# %%
chile_agg.groupby(["Left/Right","Time"])["topic_1"].mean()
# Out:
# Left/Right  Time
# Left        After     0.063466
#             Before    0.377183
#             During    0.278470
# Right       After     0.117618
#             Before    0.218319
#             During    0.379003
# Name: topic_1, dtype: float32

# %%
chile_agg.groupby(["Left/Right","Time"])["topic_2"].mean()
# Out:
# Left/Right  Time
# Left        After     0.001012
#             Before    0.005494
#             During    0.030882
# Right       After     0.000803
#             Before    0.005355
#             During    0.012435
# Name: topic_2, dtype: float32

# %%
chile_agg.groupby(["Left/Right","Time"])["topic_3"].mean()
# Out:
# Left/Right  Time
# Left        After     0.000641
#             Before    0.031574
#             During    0.010088
# Right       After     0.018745
#             Before    0.040045
#             During    0.003383
# Name: topic_3, dtype: float32

# %% [markdown]
# **Colombia**

# %%
text=col_agg['joined_text']

# %%
texts=[tokenize(document,1) for document in text]

# %%
#making bigrams and trigrams
bigram = gensim.models.Phrases(texts, min_count=1, threshold=1)
trigram = gensim.models.Phrases(bigram[texts], threshold=1)  

bigram_mod = gensim.models.phrases.Phraser(bigram)
trigram_mod = gensim.models.phrases.Phraser(trigram)

texts_bigrams = [bigram_mod[doc] for doc in texts]
texts_trigrams = [trigram_mod[doc] for doc in texts]

# %%
texts=texts_trigrams


frequency = defaultdict(int)
for text in texts:
    for token in text:
        frequency[token] += 1

texts = [
    [token for token in text if frequency[token] > 1]
    for text in texts
]

#pprint(texts)

dictionary = corpora.Dictionary(texts)
print(dictionary)

dictionary.filter_extremes(no_below = 20, no_above=0.25)
# we are getting rid of things like "said" with the no_above threshold (depending on stemming more will be thrown out)
print(dictionary)

corpus = [dictionary.doc2bow(text) for text in texts]
# Out:
# Dictionary(89441 unique tokens: ['abraz', 'abraz_enorm', 'abraz_felicit', 'abraz_gigant', 'abraz_gran']...)
# Dictionary(15819 unique tokens: ['abraz_enorm', 'abraz_gigant', 'abraz_grand', 'abrazot', 'abri_puert']...)

# %%
def create_eta(priors, etadict, ntopics):
    eta = np.full(shape=(ntopics, len(etadict)), fill_value=0.0001) # create a (ntopics, nterms) matrix and fill with low number
    for word, topic in priors.items(): # for each word in the list of priors
        keyindex = [index for index,term in etadict.items() if term==word] # look up the word in the dictionary
        if (len(keyindex)>0): # if it's in the dictionary
            eta[topic,keyindex[0]] = 500  # put a large number in there
    return eta

# %%
apriori_col={
    "policia":0,"esmad":0,"violencia":0,"humanos":0,"protesta":0,"detención":0,"desaparecido":0,"victima":0,"pistola":0,"bomba":0,"gases":0,"lacrimogeno":0, "represion":0, "manifestacion":0,  "violacion":0, "lesion":0, "sangre":0, "motin":0, "proyectiles":0, "tanqueta":0, "orden":0, "perdigones":0, "ojo":0, "ciego":0, "piedra":0, "antidisturbio":0, "disturbio":0,"arma":0, "trauma":0, "fuerza":0,'pension':1,'narcotrafico':1,'vejez':1,'salud':1,'drogas':1,'paramilitares':1,'paraco':1,'guerrilla':1,'farc':1,'educacion':1,'pobreza':1,'educacion':1, 'publica':1, 'gratuita':1,'sociales':1,'vivienda':1,'desigualdad':1, 'venezolanos':1, 'venezuela':1, 'conflicto':1, 'reclutamiento':1, 'desigualdad':1, 'alimentos':1, 'desempleo':1, 
                                         'delincuencia':1, 'crimen':1, 'bandas':1, 'terrorismo':1, 'robos':1, 'atracos':1, 'discriminacion':1, 'ilegal':1, 'populismo':1, 'transporte':1, 'trancon':1, 'movilidad':1, 'corrupcion':2, 'parapolitica':2,'vendido':2,'deshonesto':2,'ladrón':2,'robar':2,'mentir':2, 'recursos':2, 'contraloria':2, 'fiscalia':2, 'presupuesto':2, 'politicos':2, 'ratas':2, 
                                      'elecciones':2, 'escandalo':2, 'odebrecht':2, 'contratacion':2, 'mermelada':2, 'votos':2, 'sic':2, 'procuraduria':2, 'ñeñepolitica':2, 'carrusel':2, 'dinero':2,"reforma":3, "impuestos":3, "pobreza":3, "canasta":3, "precio":3, "carrasquilla":3, "ipc":3, "estrato":3,  "tributaria":3, "solaridad":3, "sostenible":3, "ley":3, 
                                           "desempleo":3, "clase":3, "recaudo":3, "deuda":3, "renta":3, "iva":3, "servicios":3, "patrimonio":3, "finanzas":3, "inversion":3, "exenciones":3, "economia":3, "ahorro":3, "recursos":3
}

# %%
porter=SnowballStemmer("spanish")
col_dict_adj={}
for key, value in apriori_col.items():
    a=porter.stem(key.lower())
    col_dict_adj[a]= value

# %%
eta = create_eta(col_dict_adj, dictionary, 10)

# %%
topicnumber=10

#alpha default is ’symmetric’: Uses a fixed symmetric prior of 1.0 / num_topics. In our case that is 0.1.

lda=models.LdaModel(corpus, id2word=dictionary, num_topics=topicnumber, 
                    random_state=42, eta=eta, alpha='symmetric')

lda.print_topics(topicnumber,20)
# Out:
# [(0,
#   '0.003*"victim" + 0.003*"orden" + 0.003*"ojo" + 0.003*"esmad" + 0.003*"desaparec" + 0.003*"lesion" + 0.003*"gas" + 0.003*"represion" + 0.003*"sangr" + 0.003*"arma" + 0.003*"polici" + 0.003*"piedr" + 0.003*"disturbi" + 0.003*"violacion" + 0.003*"bomb" + 0.003*"tanquet" + 0.003*"cieg" + 0.003*"detencion" + 0.003*"lacrimogen" + 0.003*"pistol"'),
#  (1,
#   '0.005*"buen_tard" + 0.004*"buen_dias" + 0.003*"terror" + 0.003*"venezuel" + 0.003*"aliment" + 0.003*"delincuent" + 0.003*"narcotraf" + 0.003*"popul" + 0.003*"paramilitar" + 0.003*"band" + 0.003*"farc" + 0.003*"conflict" + 0.003*"crim" + 0.003*"transport" + 0.003*"movil" + 0.003*"ilegal" + 0.003*"venezolan" + 0.003*"pension" + 0.003*"atrac" + 0.003*"viviend"'),
#  (2,
#   '0.003*"rob" + 0.003*"vot" + 0.003*"vend" + 0.003*"corrupcion" + 0.003*"diner" + 0.003*"eleccion" + 0.002*"ment" + 0.002*"rat" + 0.002*"ladron" + 0.002*"presupuest" + 0.002*"mermel" + 0.002*"escandal" + 0.002*"odebrecht" + 0.002*"fiscali" + 0.002*"ñeñepolit" + 0.002*"sic" + 0.002*"deshonest" + 0.002*"carrusel" + 0.002*"parapolit" + 0.002*"urib"'),
#  (3,
#   '0.003*"tributari" + 0.003*"ley" + 0.003*"reform" + 0.003*"servici" + 0.003*"recurs" + 0.003*"impuest" + 0.003*"carrasquill" + 0.003*"sosten" + 0.003*"iva" + 0.003*"inversion" + 0.003*"preci" + 0.003*"clas" + 0.003*"pobrez" + 0.003*"estrat" + 0.003*"ahorr" + 0.003*"desemple" + 0.003*"patrimoni" + 0.003*"recaud" + 0.003*"deud" + 0.003*"rent"'),
#  (4,
#   '0.002*"urib" + 0.001*"q" + 0.001*"the" + 0.001*"empres" + 0.001*"dialog" + 0.001*"vandal" + 0.001*"alcald" + 0.001*"bloque" + 0.001*"medellin" + 0.001*"duqu" + 0.001*"senador" + 0.001*"in" + 0.001*"of" + 0.001*"victim" + 0.001*"manifest" + 0.001*"march" + 0.001*"barranquill" + 0.001*"her" + 0.001*"and" + 0.001*"grup"'),
#  (5,
#   '0.002*"urib" + 0.002*"q" + 0.001*"alcald" + 0.001*"duqu" + 0.001*"empres" + 0.001*"vandal" + 0.001*"the" + 0.001*"much_graci" + 0.001*"carg" + 0.001*"and" + 0.001*"medellin" + 0.001*"dialog" + 0.001*"in" + 0.001*"manifest" + 0.001*"to" + 0.001*"mas" + 0.001*"debat" + 0.001*"campañ" + 0.001*"compr" + 0.001*"jug"'),
#  (6,
#   '0.003*"buen_dias" + 0.002*"urib" + 0.002*"buen_tard" + 0.002*"the" + 0.001*"q" + 0.001*"vandal" + 0.001*"recib_inform" + 0.001*"manifest" + 0.001*"duqu" + 0.001*"vot" + 0.001*"si_posibl" + 0.001*"alcald" + 0.001*"mujer" + 0.001*"fuerz_public" + 0.001*"and" + 0.001*"march" + 0.001*"tributari" + 0.001*"futbol" + 0.001*"of" + 0.001*"accion"'),
#  (7,
#   '0.002*"urib" + 0.002*"q" + 0.002*"duqu" + 0.001*"much_graci" + 0.001*"medellin" + 0.001*"hol" + 0.001*"manifest" + 0.001*"dialog" + 0.001*"alcald" + 0.001*"and" + 0.001*"vot" + 0.001*"the" + 0.001*"educ" + 0.001*"debat" + 0.001*"n_nla" + 0.001*"tributari" + 0.001*"entonc" + 0.001*"ped" + 0.001*"vandal" + 0.001*"senador"'),
#  (8,
#   '0.002*"q" + 0.002*"urib" + 0.001*"duqu" + 0.001*"manifest" + 0.001*"the" + 0.001*"medellin" + 0.001*"jueg" + 0.001*"futbol" + 0.001*"march" + 0.001*"negoci" + 0.001*"convers" + 0.001*"vandal" + 0.001*"dios" + 0.001*"and" + 0.001*"fiscal" + 0.001*"fuerz_public" + 0.001*"jajaj" + 0.001*"alcald" + 0.001*"tributari" + 0.001*"justici"'),
#  (9,
#   '0.003*"buen_dias" + 0.002*"urib" + 0.002*"buen_tard" + 0.002*"manifest" + 0.001*"q" + 0.001*"duqu" + 0.001*"recib_inform" + 0.001*"march" + 0.001*"n_nel" + 0.001*"medellin" + 0.001*"vandal" + 0.001*"futbol" + 0.001*"and" + 0.001*"fuerz_public" + 0.001*"mat" + 0.001*"si_posibl" + 0.001*"derech_human" + 0.001*"n_buen" + 0.001*"orden" + 0.001*"victim"')]

# %%
topics_col = [lda.get_document_topics(item, minimum_probability=0.00000001) for item in corpus]

# %%
for topics in range(0,10):
    col_agg["topic_"+str(topics)]=[x[topics][1] for x in topics_col]

# %%
col_agg=col_agg.reset_index(level=['author_id', 'Time'])

# %%
col_agg=col_agg.merge(map_table[["author_id","Categorie","Left/Right","author.username"]],how="left",left_on="author_id",right_on="author_id")

# %%
sns.set()

#define plotting region (1 row, 2 columns)
fig, axes = plt.subplots(1, 4)

#create boxplot in each subplot
p1=sns.barplot(data=col_agg,x="Time",y="topic_0",order=["Before","During","After"],hue="Categorie",ax=axes[0])
p2=sns.barplot(data=col_agg,x="Time",y="topic_1",order=["Before","During","After"],hue="Categorie",ax=axes[1])
p3=sns.barplot(data=col_agg,x="Time",y="topic_2",order=["Before","During","After"],hue="Categorie",ax=axes[2])
p4=sns.barplot(data=col_agg,x="Time",y="topic_3",order=["Before","During","After"],hue="Categorie",ax=axes[3])
p1.set_ylabel("Share Human Rights Violation")
p2.set_ylabel("Share Social Issues")
p3.set_ylabel("Share Corruption")
p4.set_ylabel("Share Protest Starter")
p1.set_xlabel("Human Rights Violation")
p2.set_xlabel("Social Issues")
p3.set_xlabel("Corruption")
p4.set_xlabel("Protest Starter")
# Out:
# Text(0.5, 0, 'Protest Starter')

# %%
col_agg.groupby(["Categorie","Time"])["topic_0"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.055581
#             Before    0.045276
#             During    0.060086
# Politician  After     0.016237
#             Before    0.012792
#             During    0.030005
# Name: topic_0, dtype: float32

# %%
col_agg.groupby(["Categorie","Time"])["topic_1"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.044686
#             Before    0.035790
#             During    0.034665
# Politician  After     0.047733
#             Before    0.038006
#             During    0.027255
# Name: topic_1, dtype: float32

# %%
col_agg.groupby(["Categorie","Time"])["topic_2"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.062084
#             Before    0.065630
#             During    0.059496
# Politician  After     0.074949
#             Before    0.057908
#             During    0.036880
# Name: topic_2, dtype: float32

# %%
col_agg.groupby(["Categorie","Time"])["topic_3"].mean()
# Out:
# Categorie   Time
# Celebrity   After     0.016628
#             Before    0.039525
#             During    0.056585
# Politician  After     0.057898
#             Before    0.122454
#             During    0.144763
# Name: topic_3, dtype: float32

# %%
col_agg.groupby(["Left/Right","Time"])["topic_0"].mean()
# Out:
# Left/Right  Time
# Left        After     0.016898
#             Before    0.012448
#             During    0.050745
# Right       After     0.015846
#             Before    0.013278
#             During    0.015193
# Name: topic_0, dtype: float32

# %%
col_agg.groupby(["Left/Right","Time"])["topic_1"].mean()
# Out:
# Left/Right  Time
# Left        After     0.033350
#             Before    0.020687
#             During    0.010911
# Right       After     0.063505
#             Before    0.050583
#             During    0.038946
# Name: topic_1, dtype: float32

# %%
col_agg.groupby(["Left/Right","Time"])["topic_2"].mean()
# Out:
# Left/Right  Time
# Left        After     0.079247
#             Before    0.057385
#             During    0.032739
# Right       After     0.071797
#             Before    0.058992
#             During    0.040040
# Name: topic_2, dtype: float32

# %%
col_agg.groupby(["Left/Right","Time"])["topic_3"].mean()
# Out:
# Left/Right  Time
# Left        After     0.059573
#             Before    0.151868
#             During    0.165561
# Right       After     0.057213
#             Before    0.102973
#             During    0.132465
# Name: topic_3, dtype: float32

# %% [markdown]
# **Topic Starters are big, Corruption is less important during protests, Social Issues also not, Human Rights became important**

# %% [markdown]
# ## Dictionary

# %%
from collections import Counter
import re

# %%
#Chile
Human_rights=["policia","carabinero","violencia","humanos","protesta","detención","desaparecido","paco","quemar","fuego","barricada","INDH", "represion", "lacrimogeno",
                                                 "perdigones", "ojo", "ciego", "mutilado","ddhh","dd hh"]
Social_issues=['pensión','AFP','vejez','salud','fonasa','consultorio','hospital','clínica','isapre','dignidad','educación','profesor','liceo','universidad','gratuita',
                                      'sociales','vivienda','campamentos', 'delincuencia']
Corruption=['corrupción','soborno','vendido','nepotismo','deshonesto','ladrón','robar','mentir']
Protest_starter=['metro','tren','pasaje','transporte','evadir','evasión','micro','transantiago','Hutt','alza','tarifa']

# %%
def stem_list(input_list):
    porter=SnowballStemmer("spanish")
    output=[]
    for i in input_list:
        output.append(porter.stem(i.lower()))
    return output

# %%
Human_rights=stem_list(Human_rights)
Social_issues=stem_list(Social_issues)
Corruption=stem_list(Corruption)
Protest_starter=stem_list(Protest_starter)

# %%
topic_list=[Human_rights,Social_issues,Corruption,Protest_starter]
names=["Human_rights","Social_issues","Corruption","Protest_starter"]

# %%
def dict_marker(df,dict_list,name_str):
    output_list=[]
    for s in df.stem_text:
        r= re.compile("|".join(r"\b%s\b" % w for w in dict_list))
        wordcount = Counter(re.findall(r, str(s).lower()))
        output_list.append(sum(wordcount.values()))
    df[name_str]=output_list
    df[name_str]=np.where(df[name_str]>0,1,0)
    return df

# %%
#Chile
for i in range(0,len(topic_list)):
    chile=dict_marker(chile,topic_list[i],names[i])

# %%
chile=dict_marker(chile,Human_rights,"Human_rights")
chile=dict_marker(chile,Social_issues,"Social_issues")
chile=dict_marker(chile,Corruption,"Corruption")
chile=dict_marker(chile,Protest_starter,"Protest_starter")

# %%
#Colombia
Human_rights=["policia","esmad","violencia","humanos","protesta","detención","desaparecido","victima","pistola","bomba","gases","lacrimogeno", "represion", "manifestacion", 
                                                   "violacion", "lesion", "sangre", "motin", "proyectiles", "tanqueta", "orden", "perdigones", "ojo", "ciego", "piedra", "antidisturbio", "disturbio",
                                                   "arma", "trauma", "fuerza"]
Social_issues=['pension','narcotrafico','vejez','salud','drogas','paramilitares','paraco','guerrilla','farc','educacion','pobreza','educacion', 'publica', 
                                         'gratuita','sociales','vivienda','desigualdad', 'venezolanos', 'venezuela', 'conflicto', 'reclutamiento', 'desigualdad', 'alimentos', 'desempleo', 
                                         'delincuencia', 'crimen', 'bandas', 'terrorismo', 'robos', 'atracos', 'discriminacion', 'ilegal', 'populismo', 'transporte', 'trancon', 'movilidad']
                        
Corruption=['corrupcion', 'parapolitica','vendido','deshonesto','ladrón','robar','mentir', 'recursos', 'contraloria', 'fiscalia', 'presupuesto', 'politicos', 'ratas', 
                                      'elecciones', 'escandalo', 'odebrecht', 'contratacion', 'mermelada', 'votos', 'sic', 'procuraduria', 'ñeñepolitica', 'carrusel', 'dinero']
                        
Protest_starter=["reforma", "impuestos", "pobreza", "canasta", "precio", "carrasquilla", "ipc", "estrato",  "tributaria", "solaridad", "sostenible", "ley", 
                                           "desempleo", "clase", "recaudo", "deuda", "renta", "iva", "servicios", "patrimonio", "finanzas", "inversion", "exenciones", "economia", "ahorro", 
                                            "recursos"]

# %%
#Colombia
for i in range(0,len(topic_list)):
    colombia=dict_marker(colombia,topic_list[i],names[i])

# %%
colombia.groupby(["Left/Right","Time"])["Human_rights"].mean()
# Out:
# Left/Right  Time
# Left        After     0.000699
#             Before    0.001442
#             During    0.000923
# Right       After     0.001899
#             Before    0.006136
#             During    0.000615
# Name: Human_rights, dtype: float64

# %% [markdown]
# **Chile**

# %%
fig, axs = plt.subplots(figsize=(20, 4))

chile.groupby(chile['days_since'])["Human_rights"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Human Rights Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Human Rights Tweets (in %)')

# %%
fig, axs = plt.subplots(figsize=(20, 4))

chile.groupby(chile['days_since'])["Social_issues"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Social Issues Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Social Issues Tweets (in %)')

# %%
fig, axs = plt.subplots(figsize=(20, 4))

chile.groupby(chile['days_since'])["Corruption"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Corruption Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Corruption Tweets (in %)')

# %%
fig, axs = plt.subplots(figsize=(20, 4))

chile.groupby(chile['days_since'])["Protest_starter"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Protest Starter Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Protest Starter Tweets (in %)')

# %% [markdown]
# **Colombia**

# %%
fig, axs = plt.subplots(figsize=(20, 4))

colombia.groupby(colombia['days_since'])["Human_rights"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Human Rights Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Human Rights Tweets (in %)')

# %%
fig, axs = plt.subplots(figsize=(20, 4))

colombia.groupby(colombia['days_since'])["Social_issues"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Social Issues Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Social Issues Tweets (in %)')

# %%
fig, axs = plt.subplots(figsize=(20, 4))

colombia.groupby(colombia['days_since'])["Corruption"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Corruption Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Corruption Tweets (in %)')

# %%
fig, axs = plt.subplots(figsize=(20, 4))

colombia.groupby(colombia['days_since'])["Protest_starter"].mean().plot(kind='line', rot=0, ax=axs)

plt.xlabel("Time in Days (0=Protest Start)")
plt.ylabel("Share Protest Starter Tweets (in %)")
# Out:
# Text(0, 0.5, 'Share Protest Starter Tweets (in %)')

# %% [markdown]
# **Seaborn**

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Human_rights", data=chile, hue='Categorie')
p1.set_title( "Share of Human Rights Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Human Rights Tweets")
# Out:
# Text(0, 0.5, 'Share of Human Rights Tweets')

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Social_issues", data=chile, hue='Categorie')
p1.set_title( "Share of Social Issues Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Social Issues Tweets")
# Out:
# Text(0, 0.5, 'Share of Social Issues Tweets')

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Corruption", data=chile, hue='Categorie')
p1.set_title( "Share of Corruption Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Corruption Tweets")
# Out:
# Text(0, 0.5, 'Share of Corruption Tweets')

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Protest_starter", data=chile, hue='Categorie')
p1.set_title( "Share of Protest Starter Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Protest Starter Tweets")
# Out:
# Text(0, 0.5, 'Share of Protest Starter Tweets')

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Human_rights", data=colombia, hue='Categorie')
p1.set_title( "Share of Human Rights Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Human Rights Tweets")
# Out:
# Text(0, 0.5, 'Share of Human Rights Tweets')

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Social_issues", data=colombia, hue='Categorie')
p1.set_title( "Share of Social Issues Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Social Issues Tweets")
# Out:
# Text(0, 0.5, 'Share of Social Issues Tweets')

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Social_issues", data=colombia, hue='Left/Right')
p1.set_title( "Share of Social Issues Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Social Issues Tweets")
# Out:
# Text(0, 0.5, 'Share of Social Issues Tweets')

# %%
colombia[colombia["Social_issues"]==1].groupby(["Left/Right","Time"])["sentiment"].mean()
# Out:
# Left/Right  Time
# Left        After     0.093029
#             Before    0.088786
#             During    0.080449
# Right       After     0.084367
#             Before    0.105737
#             During    0.096212
# Name: sentiment, dtype: float64

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Corruption", data=colombia, hue='Categorie')
p1.set_title( "Share of Corruption Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Corruption Tweets")
# Out:
# Text(0, 0.5, 'Share of Corruption Tweets')

# %%
fig, ax = plt.subplots(figsize = (10,6))
p1 = sns.lineplot(ax=ax, x='days_since', y="Protest_starter", data=colombia, hue='Categorie')
p1.set_title( "Share of Protest Starter Tweets")
p1.set_xlabel( "Timeline in Days (0: Start Protest)")
p1.set_ylabel( "Share of Protest Starter Tweets")
# Out:
# Text(0, 0.5, 'Share of Protest Starter Tweets')

# %% [markdown]
# ## Unused

# %%
colombian_dictionaries={'Violence_HumanRights':["policia","esmad","violencia","humanos","protesta","detención","desaparecido","victima","pistola","bomba","gases","lacrimogeno", "represion", "manifestacion", 
                                                   "violacion", "lesion", "sangre", "motin", "proyectiles", "tanqueta", "orden", "perdigones", "ojo", "ciego", "piedra", "antidisturbio", "disturbio",
                                                   "arma", "trauma", "fuerza"],
                        'Social_Issues':['pension','narcotrafico','vejez','salud','drogas','paramilitares','paraco','guerrilla','farc','educacion','pobreza','educacion', 'publica', 
                                         'gratuita','sociales','vivienda','desigualdad', 'venezolanos', 'venezuela', 'conflicto', 'reclutamiento', 'desigualdad', 'alimentos', 'desempleo', 
                                         'delincuencia', 'crimen', 'bandas', 'terrorismo', 'robos', 'atracos', 'discriminacion', 'ilegal', 'populismo', 'transporte', 'trancon', 'movilidad'],
                        
                        'Corruption':['corrupcion', 'parapolitica','vendido','deshonesto','ladrón','robar','mentir', 'recursos', 'contraloria', 'fiscalia', 'presupuesto', 'politicos', 'ratas', 
                                      'elecciones', 'escandalo', 'odebrecht', 'contratacion', 'mermelada', 'votos', 'sic', 'procuraduria', 'ñeñepolitica', 'carrusel', 'dinero'],
                        
                        'Protest _Starter':["reforma", "impuestos", "pobreza", "canasta", "precio", "carrasquilla", "ipc", "estrato",  "tributaria", "solaridad", "sostenible", "ley", 
                                           "desempleo", "clase", "recaudo", "deuda", "renta", "iva", "servicios", "patrimonio", "finanzas", "inversion", "exenciones", "economia", "ahorro", 
                                            "recursos"] }

# %%
chilean_dictionaries={'Violence_HumanRights':["policia","carabinero","violencia","humanos","protesta","detención","desaparecido","paco","quemar","fuego","barricada","INDH", "represion", "lacrimogeno",
                                                 "perdigones", "ojo", "ciego", "mutilado","ddhh","dd hh"],
                     'Social_Issues':['pensión','AFP','vejez','salud','fonasa','consultorio','hospital','clínica','isapre','dignidad','educación','profesor','liceo','universidad','gratuita',
                                      'sociales','vivienda','campamentos', 'delincuencia'],
                     'Corruption':['corrupción','soborno','vendido','nepotismo','deshonesto','ladrón','robar','mentir'],
                     'Protest_Starter':['metro','tren','pasaje','transporte','evadir','evasión','micro','transantiago','Hutt','alza','tarifa'] }

# %%
df.Categorie.value_counts()
# Out:
# Celebrity     896485
# Politician     77419
# Name: Categorie, dtype: int64

# %%
#getting emotion score for each term
import text2emotion as te
import nltk
nltk.download('omw-1.4')

output = pd.DataFrame()
for index, row in ch_pol_agg.iterrows():
    emotion=te.get_emotion(row["joined_text"])
    output = output.append(emotion, ignore_index=True)

# %%
# Define matrix,currently not needed!
from sklearn.feature_extraction.text import CountVectorizer
tf_vect = CountVectorizer(
    max_df=0.6, 
    min_df=20,
    max_features=10000
)
tf = tf_vect.fit_transform(text)
